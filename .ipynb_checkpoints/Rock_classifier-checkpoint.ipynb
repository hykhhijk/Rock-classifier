# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
import tensorflow.keras as keras
from tensorflow.keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
import cv2

# %% [markdown]
# 그래픽카드 인식 확인
# ['0.Leonardite(연갈탄)', '1.Lignite(갈탄)', '2.Charcoal(목탄)', '3.Waste(폐경석)']
# 라벨값은 한글 제거를 위하여 바꿀것이므로 미리 적어놓았다

# %%
from tensorflow.python.client import device_lib
device_lib.list_local_devices()
# Out:
# [name: "/device:CPU:0"
#  device_type: "CPU"
#  memory_limit: 268435456
#  locality {
#  }
#  incarnation: 13576264596293011351
#  xla_global_id: -1,
#  name: "/device:GPU:0"
#  device_type: "GPU"
#  memory_limit: 4851040256
#  locality {
#    bus_id: 1
#    links {
#    }
#  }
#  incarnation: 991326826372406025
#  physical_device_desc: "device: 0, name: NVIDIA GeForce GTX 1060 6GB, pci bus id: 0000:01:00.0, compute capability: 6.1"
#  xla_global_id: 416903419]

# %%
path="D:\Image_data"

# %%
labels = os.listdir(path)

# %% [markdown]
# **폴더를 하나씩 돌며 이미지를 읽어보면 원래 픽셀 값(4032, 3024)로 읽어들일시 첫번째 폴더를 읽지 못하고 메모리가 터짐**
# OpenCV(4.5.1) ..\modules\core\src\alloc.cpp:73: error: (-4:Insufficient memory) Failed to allocate 36578304 bytes in function 'cv::OutOfMemoryError'

# %%
### (250, 250)픽셀로 읽어 들이는데 19분
img_list=[]
label_list=[]
for i in os.listdir(path):
    print("Progressing...")
    for j in os.listdir(os.path.join(path, i)):
        img = cv2.imread(os.path.join(path, i, j))
        img = cv2.resize(img, (250, 250), interpolation=cv2.INTER_LINEAR)
        img_list.append(img)
        label_list.append(i)
# Out:
# Progressing...
# Progressing...
# Progressing...
# Progressing...

# %%
img_list = np.arra
# Out:
# (7280, 250, 250, 3)

# %%
os.path.join(path, i, j)
# Out:
# 'D:\\Image_data\\0\\Leonardite_L (158).jpg'

# %%
img.shape
# Out:
# (4032, 3024, 3)

# %%
plt.imshow(img)

# %%
os.path.join(path, labels[0])+"/Leonardite (1).jpg"
# Out:
# 'D:연갈탄 선별장치 이미지데이터(총 7,280장)/연갈탄 선별장치 이미지데이터(총 7,280장)\\0.Leonardite(연갈탄)/Leonardite (1).jpg'

# %%
labels
# Out:
# ['0.Leonardite(연갈탄)', '1.Lignite(갈탄)', '2.Charcoal(목탄)', '3.Waste(폐경석)']

# %%
labels
# Out:
# ['0', '1', '2', '3']

# %%
Input = keras.layers.Input(shape=(28, 28, 1))
x = keras.layers.Conv2D(16, kernel_size=14, padding="same")(Input)
x = keras.layers.Flatten()(x)
Output = keras.layers.Dense(10, activation="softmax")(x)

model = keras.models.Model(inputs = Input, outputs = Output)

# %%
model.compile(loss="sparse_categorical_crossentropy", optimizer="adam", metrics=["accuracy"])
history = model.fit(train_images,train_labels, epochs=3, validation_data=(test_images, test_labels))
# Out:
# Epoch 1/3
# 1875/1875 [==============================] - 11s 5ms/step - loss: 16.9272 - accuracy: 0.7467 - val_loss: 23.4759 - val_accuracy: 0.7800
# Epoch 2/3
# 1875/1875 [==============================] - 10s 5ms/step - loss: 11.4777 - accuracy: 0.7736 - val_loss: 17.3876 - val_accuracy: 0.7393
# Epoch 3/3
# 1875/1875 [==============================] - 10s 5ms/step - loss: 14.6481 - accuracy: 0.7737 - val_loss: 11.8314 - val_accuracy: 0.7631

# %%
train_images = train_images.reshape(train_images.shape[0],train_images.shape[1], train_images.shape[2],-1 )

# %%
test_images = test_images.reshape(test_images.shape[0],train_images.shape[1], train_images.shape[2],-1 )

# %%
train_images.shape
# Out:
# (60000, 28, 28, 1)

# %%
pd.Series(train_labels).value_counts()
# Out:
# 9    6000
# 0    6000
# 3    6000
# 2    6000
# 7    6000
# 5    6000
# 1    6000
# 6    6000
# 4    6000
# 8    6000
# dtype: int64

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
import tensorflow.keras as keras
import cv2
import joblib
from sklearn.preprocessing import OneHotEncoder
from sklearn.model_selection import train_test_split
import albumentations as A
import time

# %%
X = joblib.load("CV2_60.pkl")
y = joblib.load("label.pkl")

# %% [markdown]
# To pass an image to the augmentation pipeline you need to call the transform function created by a call to A.Compose at Step 2. In the image argument to that function, you need to pass an image that you want to augment.

# %%
fig = plt.figure(figsize=(14, 10))
for i in range(1, 17):
    ax = plt.subplot(4, 4, i)
    ax.axes.xaxis.set_visible(False)
    ax.axes.yaxis.set_visible(False)
    plt.imshow(X[i])

# %%
X = np.float32(X)

# %%
encoder = OneHotEncoder(sparse=False)
encoder.fit(y.reshape(-1, 1))
# Out:
# OneHotEncoder(sparse=False)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=y, shuffle=True)
y_test = encoder.transform(y_test.reshape(-1, 1))

test_trainsform = A.Compose([
A.Resize(32, 32)
])

img_list=[]
for i in range(len(X_test)):
    img_list.append(test_trainsform(image=X_test[i])["image"])
img_list = np.float32(img_list)
X_test = img_list

# %%
transform_crop = A.Compose([
    A.Resize(40, 40),
    A.RandomCrop(32, 32),
    A.OneOf([
    A.HorizontalFlip(p=1), 
    A.VerticalFlip(p=1)],p=1)
])

# %%
transform_flip_bright = A.Compose([
    A.Resize(32, 32),
    A.HorizontalFlip(p=0.5), 
    A.VerticalFlip(p=0.5),
    A.RandomBrightness(p=0.5, limit=(-0.25, 0.25))
])
# Out:
# C:\Users\hjhhi\anaconda3\envs\python3.9.0\lib\site-packages\albumentations\augmentations\transforms.py:1800: FutureWarning: This class has been deprecated. Please use RandomBrightnessContrast
#   warnings.warn(

# %%
transform_fiip = A.Compose([
    A.Resize(32, 32),
    A.HorizontalFlip(p=0.5), 
    A.VerticalFlip(p=0.5),
])

# %%
def make_train_data(augment):
    img_list = []
    label_list = []
    for _ in range(10):
        for i in range(len(X_train)):
            img_list.append(augment(image=X_train[i])["image"])
            label_list.append(y_train[i])
    img_list = np.float32(img_list)
    img_list = img_list.reshape(-1, 32, 32, 3)
    label_list = np.float32(label_list)
    return [img_list, label_list]

# %% [markdown]
# # Augmentation model

# %%
es = keras.callbacks.EarlyStopping(monitor="val_accuracy", patience=10, mode="max")

# %%
reduce_lr = keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.5,patience=3, min_lr=0.00001, verbose=1)

# %%
history_list=[]

for i in [transform_crop, transform_fiip, transform_flip_bright]:
    X_train_, y_train_ = make_train_data(i)
    y_train_ = y_train_.reshape(-1, 1)
    y_train_ = encoder.transform(y_train_)
    
    dr_ratio=0.2

    Input = keras.layers.Input(shape=X_train_[0].shape)

    x = keras.layers.Conv2D(16, kernel_size=3, activation="relu",kernel_initializer="he_normal", padding="same")(Input)
    x = keras.layers.BatchNormalization()(x)
    x = keras.layers.MaxPool2D(2)(x)

    x = keras.layers.Dropout(dr_ratio)(x)

    shortcut =x
    x = keras.layers.Conv2D(32, kernel_size=3, activation="relu",kernel_initializer="he_normal", padding="same")(x)
    x = keras.layers.BatchNormalization()(x)
    x = keras.layers.Conv2D(32, kernel_size=3, activation="relu",kernel_initializer="he_normal", padding="same")(x)
    # x = keras.layers.BatchNormalization()(x)
    # x = keras.layers.Conv2D(32, kernel_size=3, activation="relu",kernel_initializer="he_normal", padding="same")(x)
    shortcut = keras.layers.Conv2D(32, kernel_size=5, activation="relu",kernel_initializer="he_normal", padding="same")(shortcut)
    x = keras.layers.Add()([x, shortcut])
    x   = keras.layers.BatchNormalization()(x)
    x = keras.layers.MaxPool2D(2)(x)


    x = keras.layers.Dropout(dr_ratio)(x)


    shortcut =x
    x = keras.layers.Conv2D(64, kernel_size=3, activation="relu",kernel_initializer="he_normal", padding="same")(x)
    x = keras.layers.BatchNormalization()(x)
    x = keras.layers.Conv2D(64, kernel_size=3, activation="relu",kernel_initializer="he_normal", padding="same")(x)
    # x = keras.layers.BatchNormalization()(x)
    # x = keras.layers.Conv2D(64, kernel_size=3, activation="relu",kernel_initializer="he_normal", padding="same")(x)
    shortcut = keras.layers.Conv2D(64, kernel_size=3, activation="relu",kernel_initializer="he_normal", padding="same")(shortcut)
    x = keras.layers.Add()([x, shortcut])
    x = keras.layers.BatchNormalization()(x)
    x = keras.layers.MaxPool2D(2)(x)

    x = keras.layers.Dropout(dr_ratio)(x)

    shortcut =x
    x = keras.layers.Conv2D(128, kernel_size=3, activation="relu",kernel_initializer="he_normal", padding="same")(x)
    x = keras.layers.BatchNormalization()(x)
    x = keras.layers.Conv2D(128, kernel_size=3, activation="relu",kernel_initializer="he_normal", padding="same")(x)
    # x = keras.layers.BatchNormalization()(x)
    # x = keras.layers.Conv2D(128, kernel_size=3, activation="relu",kernel_initializer="he_normal", padding="same")(x)
    shortcut = keras.layers.Conv2D(128, kernel_size=3, activation="relu",kernel_initializer="he_normal", padding="same")(shortcut)
    x = keras.layers.Add()([x, shortcut])
    x = keras.layers.BatchNormalization()(x)
    x = keras.layers.MaxPool2D(2)(x)

    x = keras.layers.Dropout(dr_ratio)(x)


    x = keras.layers.GlobalAveragePooling2D()(x)
    Output = keras.layers.Dense(4, activation="softmax")(x)

    model = keras.models.Model(inputs = Input, outputs = Output)
    model.compile(loss="categorical_crossentropy",
    optimizer=keras.optimizers.Adam(learning_rate=0.001), metrics=["accuracy"])

    history_list.append(model.fit(X_train_, y_train_, validation_data=(X_test, y_test),callbacks=[es, reduce_lr],epochs = 100))
    print("Train: ", model.evaluate(X_train_, y_train_))
    print("Valid: ", model.evaluate(X_test, y_test))
# Out:
# Epoch 1/100
# 1707/1707 [==============================] - 22s 11ms/step - loss: 0.4855 - accuracy: 0.7995 - val_loss: 0.3970 - val_accuracy: 0.8544
# Epoch 2/100
# 1707/1707 [==============================] - 19s 11ms/step - loss: 0.2298 - accuracy: 0.9134 - val_loss: 0.5106 - val_accuracy: 0.8374
# Epoch 3/100
# 1707/1707 [==============================] - 19s 11ms/step - loss: 0.1572 - accuracy: 0.9416 - val_loss: 0.2318 - val_accuracy: 0.9154
# Epoch 4/100
# 1707/1707 [==============================] - 19s 11ms/step - loss: 0.1206 - accuracy: 0.9551 - val_loss: 0.8402 - val_accuracy: 0.7577
# Epoch 5/100
# 1707/1707 [==============================] - 19s 11ms/step - loss: 0.0914 - accuracy: 0.9665 - val_loss: 1.0533 - val_accuracy: 0.7467
# Epoch 6/100
# 1707/1707 [==============================] - 19s 11ms/step - loss: 0.0741 - accuracy: 0.9739 - val_loss: 0.3825 - val_accuracy: 0.8813
#
# Epoch 00006: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 7/100
# 1707/1707 [==============================] - 19s 11ms/step - loss: 0.0424 - accuracy: 0.9851 - val_loss: 0.3201 - val_accuracy: 0.9071
# Epoch 8/100
# 1707/1707 [==============================] - 19s 11ms/step - loss: 0.0366 - accuracy: 0.9868 - val_loss: 0.2425 - val_accuracy: 0.9297
# Epoch 9/100
# 1707/1707 [==============================] - 19s 11ms/step - loss: 0.0334 - accuracy: 0.9879 - val_loss: 0.3424 - val_accuracy: 0.9000
#
# Epoch 00009: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Epoch 10/100
# 1707/1707 [==============================] - 19s 11ms/step - loss: 0.0195 - accuracy: 0.9933 - val_loss: 0.2518 - val_accuracy: 0.9319
# Epoch 11/100
# 1707/1707 [==============================] - 19s 11ms/step - loss: 0.0182 - accuracy: 0.9938 - val_loss: 0.2769 - val_accuracy: 0.9165
# Epoch 12/100
# 1707/1707 [==============================] - 18s 11ms/step - loss: 0.0148 - accuracy: 0.9946 - val_loss: 0.2044 - val_accuracy: 0.9418
# Epoch 13/100
# 1707/1707 [==============================] - 19s 11ms/step - loss: 0.0154 - accuracy: 0.9946 - val_loss: 0.4216 - val_accuracy: 0.8918
# Epoch 14/100
# 1707/1707 [==============================] - 19s 11ms/step - loss: 0.0152 - accuracy: 0.9952 - val_loss: 0.2657 - val_accuracy: 0.9335
# Epoch 15/100
# 1707/1707 [==============================] - 19s 11ms/step - loss: 0.0132 - accuracy: 0.9952 - val_loss: 0.6298 - val_accuracy: 0.8769
#
# Epoch 00015: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# Epoch 16/100
# 1707/1707 [==============================] - 19s 11ms/step - loss: 0.0093 - accuracy: 0.9970 - val_loss: 0.2501 - val_accuracy: 0.9467
# Epoch 17/100
# 1707/1707 [==============================] - 19s 11ms/step - loss: 0.0087 - accuracy: 0.9970 - val_loss: 0.8791 - val_accuracy: 0.8286
# Epoch 18/100
# 1707/1707 [==============================] - 19s 11ms/step - loss: 0.0086 - accuracy: 0.9972 - val_loss: 0.2058 - val_accuracy: 0.9500: 0s - loss: 0.0
#
# Epoch 00018: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# Epoch 19/100
# 1707/1707 [==============================] - 19s 11ms/step - loss: 0.0070 - accuracy: 0.9977 - val_loss: 0.2205 - val_accuracy: 0.9434
# Epoch 20/100
# 1707/1707 [==============================] - 19s 11ms/step - loss: 0.0051 - accuracy: 0.9982 - val_loss: 0.2596 - val_accuracy: 0.9374
# Epoch 21/100
# 1707/1707 [==============================] - 19s 11ms/step - loss: 0.0062 - accuracy: 0.9980 - val_loss: 0.2173 - val_accuracy: 0.9478
#
# Epoch 00021: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# Epoch 22/100
# 1707/1707 [==============================] - 19s 11ms/step - loss: 0.0048 - accuracy: 0.9985 - val_loss: 0.2346 - val_accuracy: 0.9478
# Epoch 23/100
# 1707/1707 [==============================] - 19s 11ms/step - loss: 0.0049 - accuracy: 0.9986 - val_loss: 0.2081 - val_accuracy: 0.9434
# Epoch 24/100
# 1707/1707 [==============================] - 19s 11ms/step - loss: 0.0053 - accuracy: 0.9981 - val_loss: 0.2126 - val_accuracy: 0.9527
#
# Epoch 00024: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# Epoch 25/100
# 1707/1707 [==============================] - 19s 11ms/step - loss: 0.0046 - accuracy: 0.9986 - val_loss: 0.2064 - val_accuracy: 0.9511
# Epoch 26/100
# 1707/1707 [==============================] - 19s 11ms/step - loss: 0.0041 - accuracy: 0.9988 - val_loss: 0.2125 - val_accuracy: 0.9489
# Epoch 27/100
# 1707/1707 [==============================] - 19s 11ms/step - loss: 0.0049 - accuracy: 0.9985 - val_loss: 0.2326 - val_accuracy: 0.9462
#
# Epoch 00027: ReduceLROnPlateau reducing learning rate to 1e-05.
# Epoch 28/100
# 1707/1707 [==============================] - 19s 11ms/step - loss: 0.0049 - accuracy: 0.9986 - val_loss: 0.2145 - val_accuracy: 0.9440
# Epoch 29/100
# 1707/1707 [==============================] - 19s 11ms/step - loss: 0.0044 - accuracy: 0.9987 - val_loss: 0.2112 - val_accuracy: 0.9467
# Epoch 30/100
# 1707/1707 [==============================] - 19s 11ms/step - loss: 0.0041 - accuracy: 0.9988 - val_loss: 0.1987 - val_accuracy: 0.9489
# Epoch 31/100
# 1707/1707 [==============================] - 19s 11ms/step - loss: 0.0040 - accuracy: 0.9988 - val_loss: 0.2046 - val_accuracy: 0.9484
# Epoch 32/100
# 1707/1707 [==============================] - 19s 11ms/step - loss: 0.0042 - accuracy: 0.9985 - val_loss: 0.2061 - val_accuracy: 0.9467
# Epoch 33/100
# 1707/1707 [==============================] - 19s 11ms/step - loss: 0.0046 - accuracy: 0.9986 - val_loss: 0.1860 - val_accuracy: 0.9522
# Epoch 34/100
# 1707/1707 [==============================] - 19s 11ms/step - loss: 0.0039 - accuracy: 0.9990 - val_loss: 0.2062 - val_accuracy: 0.9478
# 1707/1707 [==============================] - 8s 5ms/step - loss: 1.2625e-04 - accuracy: 1.0000
# Train:  [0.00012624956434592605, 1.0]
# 57/57 [==============================] - 0s 5ms/step - loss: 0.2062 - accuracy: 0.9478
# Valid:  [0.20619136095046997, 0.9478021860122681]
# Epoch 1/100
# 1707/1707 [==============================] - 20s 11ms/step - loss: 0.4135 - accuracy: 0.8316 - val_loss: 0.5969 - val_accuracy: 0.8269
# Epoch 2/100
# 1707/1707 [==============================] - 19s 11ms/step - loss: 0.1415 - accuracy: 0.9473 - val_loss: 0.2827 - val_accuracy: 0.8989
# Epoch 3/100
# 1707/1707 [==============================] - 19s 11ms/step - loss: 0.0978 - accuracy: 0.9632 - val_loss: 0.1002 - val_accuracy: 0.9654
# Epoch 4/100
# 1707/1707 [==============================] - 18s 11ms/step - loss: 0.0668 - accuracy: 0.9760 - val_loss: 1.5803 - val_accuracy: 0.7500
# Epoch 5/100
# 1707/1707 [==============================] - 19s 11ms/step - loss: 0.0544 - accuracy: 0.9808 - val_loss: 0.2957 - val_accuracy: 0.9005
# Epoch 6/100
# 1707/1707 [==============================] - 19s 11ms/step - loss: 0.0415 - accuracy: 0.9851 - val_loss: 0.2502 - val_accuracy: 0.9209
#
# Epoch 00006: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 7/100
# 1707/1707 [==============================] - 19s 11ms/step - loss: 0.0187 - accuracy: 0.9935 - val_loss: 0.0686 - val_accuracy: 0.9736
# Epoch 8/100
# 1707/1707 [==============================] - 19s 11ms/step - loss: 0.0173 - accuracy: 0.9942 - val_loss: 0.1981 - val_accuracy: 0.9440
# Epoch 9/100
# 1707/1707 [==============================] - 19s 11ms/step - loss: 0.0150 - accuracy: 0.9950 - val_loss: 0.0652 - val_accuracy: 0.9797
# Epoch 10/100
# 1707/1707 [==============================] - 19s 11ms/step - loss: 0.0138 - accuracy: 0.9951 - val_loss: 0.9300 - val_accuracy: 0.8407
# Epoch 11/100
# 1707/1707 [==============================] - 19s 11ms/step - loss: 0.0125 - accuracy: 0.9955 - val_loss: 0.1258 - val_accuracy: 0.9615
# Epoch 12/100
# 1707/1707 [==============================] - 19s 11ms/step - loss: 0.0111 - accuracy: 0.9960 - val_loss: 2.0477 - val_accuracy: 0.6588
#
# Epoch 00012: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Epoch 13/100
# 1707/1707 [==============================] - 19s 11ms/step - loss: 0.0047 - accuracy: 0.9986 - val_loss: 0.0174 - val_accuracy: 0.9951
# Epoch 14/100
# 1707/1707 [==============================] - 19s 11ms/step - loss: 0.0045 - accuracy: 0.9986 - val_loss: 0.0207 - val_accuracy: 0.9951
# Epoch 15/100
# 1707/1707 [==============================] - 18s 11ms/step - loss: 0.0047 - accuracy: 0.9983 - val_loss: 0.0431 - val_accuracy: 0.9885
# Epoch 16/100
# 1707/1707 [==============================] - 18s 11ms/step - loss: 0.0059 - accuracy: 0.9983 - val_loss: 0.0429 - val_accuracy: 0.9874
#
# Epoch 00016: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# Epoch 17/100
# 1707/1707 [==============================] - 18s 11ms/step - loss: 0.0030 - accuracy: 0.9990 - val_loss: 0.0176 - val_accuracy: 0.9956
# Epoch 18/100
# 1707/1707 [==============================] - 18s 10ms/step - loss: 0.0021 - accuracy: 0.9993 - val_loss: 0.0142 - val_accuracy: 0.9962
# Epoch 19/100
# 1707/1707 [==============================] - 18s 10ms/step - loss: 0.0026 - accuracy: 0.9993 - val_loss: 0.0232 - val_accuracy: 0.9967
# Epoch 20/100
# 1707/1707 [==============================] - 18s 10ms/step - loss: 0.0015 - accuracy: 0.9996 - val_loss: 0.0253 - val_accuracy: 0.9956
# Epoch 21/100
# 1707/1707 [==============================] - 18s 10ms/step - loss: 0.0018 - accuracy: 0.9994 - val_loss: 0.0204 - val_accuracy: 0.9962
#
# Epoch 00021: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# Epoch 22/100
# 1707/1707 [==============================] - 18s 11ms/step - loss: 0.0017 - accuracy: 0.9995 - val_loss: 0.0393 - val_accuracy: 0.9885
# Epoch 23/100
# 1707/1707 [==============================] - 18s 11ms/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.0177 - val_accuracy: 0.9967
# Epoch 24/100
# 1707/1707 [==============================] - 19s 11ms/step - loss: 0.0012 - accuracy: 0.9996 - val_loss: 0.0172 - val_accuracy: 0.9973
#
# Epoch 00024: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# Epoch 25/100
# 1707/1707 [==============================] - 18s 11ms/step - loss: 7.9507e-04 - accuracy: 0.9998 - val_loss: 0.0169 - val_accuracy: 0.9967
# Epoch 26/100
# 1707/1707 [==============================] - 18s 11ms/step - loss: 9.6502e-04 - accuracy: 0.9997 - val_loss: 0.0163 - val_accuracy: 0.9962
# Epoch 27/100
# 1707/1707 [==============================] - 18s 11ms/step - loss: 6.1579e-04 - accuracy: 0.9999 - val_loss: 0.0192 - val_accuracy: 0.9951
#
# Epoch 00027: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# Epoch 28/100
# 1707/1707 [==============================] - 18s 11ms/step - loss: 8.8473e-04 - accuracy: 0.9997 - val_loss: 0.0156 - val_accuracy: 0.9973
# Epoch 29/100
# 1707/1707 [==============================] - 18s 11ms/step - loss: 9.0920e-04 - accuracy: 0.9997 - val_loss: 0.0159 - val_accuracy: 0.9967
# Epoch 30/100
# 1707/1707 [==============================] - 18s 11ms/step - loss: 8.3132e-04 - accuracy: 0.9998 - val_loss: 0.0156 - val_accuracy: 0.9967
#
# Epoch 00030: ReduceLROnPlateau reducing learning rate to 1e-05.
# Epoch 31/100
# 1707/1707 [==============================] - 18s 11ms/step - loss: 6.7486e-04 - accuracy: 0.9998 - val_loss: 0.0167 - val_accuracy: 0.9973
# Epoch 32/100
# 1707/1707 [==============================] - 18s 11ms/step - loss: 8.2527e-04 - accuracy: 0.9998 - val_loss: 0.0168 - val_accuracy: 0.9967
# Epoch 33/100
# 1707/1707 [==============================] - 18s 11ms/step - loss: 7.9921e-04 - accuracy: 0.9998 - val_loss: 0.0157 - val_accuracy: 0.9973
# Epoch 34/100
# 1707/1707 [==============================] - 18s 11ms/step - loss: 6.5993e-04 - accuracy: 0.9999 - val_loss: 0.0167 - val_accuracy: 0.9967
# 1707/1707 [==============================] - 8s 5ms/step - loss: 5.1144e-06 - accuracy: 1.0000
# Train:  [5.114426585350884e-06, 1.0]
# 57/57 [==============================] - 0s 4ms/step - loss: 0.0167 - accuracy: 0.9967
# Valid:  [0.016702763736248016, 0.9967032670974731]
# Epoch 1/100
# 1707/1707 [==============================] - 19s 11ms/step - loss: 0.5123 - accuracy: 0.7935 - val_loss: 0.2586 - val_accuracy: 0.9038
# Epoch 2/100
# 1707/1707 [==============================] - 18s 11ms/step - loss: 0.2095 - accuracy: 0.9218 - val_loss: 0.6284 - val_accuracy: 0.8181
# Epoch 3/100
# 1707/1707 [==============================] - 18s 10ms/step - loss: 0.1397 - accuracy: 0.9482 - val_loss: 0.1195 - val_accuracy: 0.9582
# Epoch 4/100
# 1707/1707 [==============================] - 18s 10ms/step - loss: 0.1031 - accuracy: 0.9634 - val_loss: 0.1291 - val_accuracy: 0.95770s - loss: 0.1034  - ETA: 0s - loss: 0.1032 - accuracy: 0.
# Epoch 5/100
# 1707/1707 [==============================] - 18s 11ms/step - loss: 0.0801 - accuracy: 0.9708 - val_loss: 0.0560 - val_accuracy: 0.9797
# Epoch 6/100
# 1707/1707 [==============================] - 18s 10ms/step - loss: 0.0666 - accuracy: 0.9750 - val_loss: 0.0383 - val_accuracy: 0.9874
# Epoch 7/100
# 1707/1707 [==============================] - 18s 10ms/step - loss: 0.0559 - accuracy: 0.9802 - val_loss: 0.1525 - val_accuracy: 0.9538
# Epoch 8/100
# 1707/1707 [==============================] - 18s 10ms/step - loss: 0.0481 - accuracy: 0.9827 - val_loss: 0.1681 - val_accuracy: 0.9489
# Epoch 9/100
# 1707/1707 [==============================] - 18s 10ms/step - loss: 0.0481 - accuracy: 0.9836 - val_loss: 0.0791 - val_accuracy: 0.9692
#
# Epoch 00009: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 10/100
# 1707/1707 [==============================] - 18s 10ms/step - loss: 0.0188 - accuracy: 0.9937 - val_loss: 0.0384 - val_accuracy: 0.9863
# Epoch 11/100
# 1707/1707 [==============================] - 18s 10ms/step - loss: 0.0192 - accuracy: 0.9932 - val_loss: 0.1465 - val_accuracy: 0.9549
# Epoch 12/100
# 1707/1707 [==============================] - 18s 10ms/step - loss: 0.0178 - accuracy: 0.9939 - val_loss: 0.0332 - val_accuracy: 0.9901
# Epoch 13/100
# 1707/1707 [==============================] - 18s 10ms/step - loss: 0.0164 - accuracy: 0.9946 - val_loss: 0.0604 - val_accuracy: 0.9841
# Epoch 14/100
# 1707/1707 [==============================] - 18s 10ms/step - loss: 0.0157 - accuracy: 0.9945 - val_loss: 0.0485 - val_accuracy: 0.9852
# Epoch 15/100
# 1707/1707 [==============================] - 18s 10ms/step - loss: 0.0156 - accuracy: 0.9945 - val_loss: 0.1234 - val_accuracy: 0.9720
#
# Epoch 00015: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Epoch 16/100
# 1707/1707 [==============================] - 18s 10ms/step - loss: 0.0082 - accuracy: 0.9972 - val_loss: 0.0440 - val_accuracy: 0.9907
# Epoch 17/100
# 1707/1707 [==============================] - 18s 10ms/step - loss: 0.0073 - accuracy: 0.9977 - val_loss: 0.0381 - val_accuracy: 0.9901
# Epoch 18/100
# 1707/1707 [==============================] - 18s 10ms/step - loss: 0.0069 - accuracy: 0.9976 - val_loss: 0.0278 - val_accuracy: 0.9929
# Epoch 19/100
# 1707/1707 [==============================] - 18s 11ms/step - loss: 0.0063 - accuracy: 0.9980 - val_loss: 0.0217 - val_accuracy: 0.9945
# Epoch 20/100
# 1707/1707 [==============================] - 18s 10ms/step - loss: 0.0068 - accuracy: 0.9977 - val_loss: 0.0337 - val_accuracy: 0.9912
# Epoch 21/100
# 1707/1707 [==============================] - 18s 10ms/step - loss: 0.0066 - accuracy: 0.9979 - val_loss: 0.0383 - val_accuracy: 0.9890
# Epoch 22/100
# 1707/1707 [==============================] - 18s 11ms/step - loss: 0.0071 - accuracy: 0.9976 - val_loss: 0.0241 - val_accuracy: 0.9951
#
# Epoch 00022: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# Epoch 23/100
# 1707/1707 [==============================] - 18s 11ms/step - loss: 0.0046 - accuracy: 0.9985 - val_loss: 0.0250 - val_accuracy: 0.9951
# Epoch 24/100
# 1707/1707 [==============================] - 18s 10ms/step - loss: 0.0037 - accuracy: 0.9989 - val_loss: 0.0201 - val_accuracy: 0.9951
# Epoch 25/100
# 1707/1707 [==============================] - 18s 10ms/step - loss: 0.0038 - accuracy: 0.9989 - val_loss: 0.0401 - val_accuracy: 0.9890
# Epoch 26/100
# 1707/1707 [==============================] - 18s 10ms/step - loss: 0.0031 - accuracy: 0.9991 - val_loss: 0.0223 - val_accuracy: 0.9945033 - accuracy: 0.999 - ETA: 15s - loss: 0.0032 - accuracy: 0 - ETA: 15s - loss: 0.0030 - accuracy: 0 - ETA: 14s - loss: 0.0029 - accura - ETA: 14s - loss: 0.0028  - ETA
# Epoch 27/100
# 1707/1707 [==============================] - 18s 10ms/step - loss: 0.0030 - accuracy: 0.9991 - val_loss: 0.0184 - val_accuracy: 0.9962
# Epoch 28/100
# 1707/1707 [==============================] - 18s 10ms/step - loss: 0.0036 - accuracy: 0.9989 - val_loss: 0.0182 - val_accuracy: 0.9967
# Epoch 29/100
# 1707/1707 [==============================] - 18s 10ms/step - loss: 0.0029 - accuracy: 0.9990 - val_loss: 0.0228 - val_accuracy: 0.9940
# Epoch 30/100
# 1707/1707 [==============================] - 18s 10ms/step - loss: 0.0027 - accuracy: 0.9991 - val_loss: 0.0199 - val_accuracy: 0.99670s - loss: 0.002
# Epoch 31/100
# 1707/1707 [==============================] - 18s 10ms/step - loss: 0.0032 - accuracy: 0.9991 - val_loss: 0.0166 - val_accuracy: 0.9967
# Epoch 32/100
# 1707/1707 [==============================] - 18s 10ms/step - loss: 0.0031 - accuracy: 0.9990 - val_loss: 0.0157 - val_accuracy: 0.9978
# Epoch 33/100
# 1707/1707 [==============================] - 18s 10ms/step - loss: 0.0031 - accuracy: 0.9991 - val_loss: 0.0297 - val_accuracy: 0.9929
# Epoch 34/100
# 1707/1707 [==============================] - 18s 10ms/step - loss: 0.0031 - accuracy: 0.9990 - val_loss: 0.0509 - val_accuracy: 0.9890
# Epoch 35/100
# 1707/1707 [==============================] - 18s 10ms/step - loss: 0.0028 - accuracy: 0.9991 - val_loss: 0.0234 - val_accuracy: 0.9956
#
# Epoch 00035: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# Epoch 36/100
# 1707/1707 [==============================] - 18s 10ms/step - loss: 0.0023 - accuracy: 0.9992 - val_loss: 0.0298 - val_accuracy: 0.9934
# Epoch 37/100
# 1707/1707 [==============================] - 18s 10ms/step - loss: 0.0018 - accuracy: 0.9994 - val_loss: 0.0227 - val_accuracy: 0.9962
# Epoch 38/100
# 1707/1707 [==============================] - 18s 10ms/step - loss: 0.0020 - accuracy: 0.9994 - val_loss: 0.0201 - val_accuracy: 0.9951
#
# Epoch 00038: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# Epoch 39/100
# 1707/1707 [==============================] - 18s 11ms/step - loss: 0.0017 - accuracy: 0.9995 - val_loss: 0.0199 - val_accuracy: 0.9962
# Epoch 40/100
# 1707/1707 [==============================] - 18s 11ms/step - loss: 0.0018 - accuracy: 0.9994 - val_loss: 0.0205 - val_accuracy: 0.9951
# Epoch 41/100
# 1707/1707 [==============================] - 18s 10ms/step - loss: 0.0015 - accuracy: 0.9995 - val_loss: 0.0211 - val_accuracy: 0.9951
#
# Epoch 00041: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# Epoch 42/100
# 1707/1707 [==============================] - 18s 10ms/step - loss: 0.0015 - accuracy: 0.9996 - val_loss: 0.0203 - val_accuracy: 0.9956
# 1707/1707 [==============================] - 8s 5ms/step - loss: 7.9430e-05 - accuracy: 1.0000
# Train:  [7.943031960166991e-05, 0.999981701374054]
# 57/57 [==============================] - 0s 5ms/step - loss: 0.0203 - accuracy: 0.9956
# Valid:  [0.020332254469394684, 0.995604395866394]

# %% [markdown]
# # Original data model

# %%
X = joblib.load("CV2_float32.pkl")

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=y, shuffle=True)

# %%
y_train = encoder.transform(y_train.reshape(-1, 1))
y_test = encoder.transform(y_test.reshape(-1, 1))

# %%
dr_ratio=0.2

Input = keras.layers.Input(shape=X_train[0].shape)

x = keras.layers.Conv2D(16, kernel_size=3, activation="relu",kernel_initializer="he_normal", padding="same")(Input)
x = keras.layers.BatchNormalization()(x)
x = keras.layers.MaxPool2D(2)(x)

x = keras.layers.Dropout(dr_ratio)(x)

shortcut =x
x = keras.layers.Conv2D(32, kernel_size=3, activation="relu",kernel_initializer="he_normal", padding="same")(x)
x = keras.layers.BatchNormalization()(x)
x = keras.layers.Conv2D(32, kernel_size=3, activation="relu",kernel_initializer="he_normal", padding="same")(x)
# x = keras.layers.BatchNormalization()(x)
# x = keras.layers.Conv2D(32, kernel_size=3, activation="relu",kernel_initializer="he_normal", padding="same")(x)
shortcut = keras.layers.Conv2D(32, kernel_size=5, activation="relu",kernel_initializer="he_normal", padding="same")(shortcut)
x = keras.layers.Add()([x, shortcut])
x   = keras.layers.BatchNormalization()(x)
x = keras.layers.MaxPool2D(2)(x)


x = keras.layers.Dropout(dr_ratio)(x)


shortcut =x
x = keras.layers.Conv2D(64, kernel_size=3, activation="relu",kernel_initializer="he_normal", padding="same")(x)
x = keras.layers.BatchNormalization()(x)
x = keras.layers.Conv2D(64, kernel_size=3, activation="relu",kernel_initializer="he_normal", padding="same")(x)
# x = keras.layers.BatchNormalization()(x)
# x = keras.layers.Conv2D(64, kernel_size=3, activation="relu",kernel_initializer="he_normal", padding="same")(x)
shortcut = keras.layers.Conv2D(64, kernel_size=3, activation="relu",kernel_initializer="he_normal", padding="same")(shortcut)
x = keras.layers.Add()([x, shortcut])
x = keras.layers.BatchNormalization()(x)
x = keras.layers.MaxPool2D(2)(x)

x = keras.layers.Dropout(dr_ratio)(x)

shortcut =x
x = keras.layers.Conv2D(128, kernel_size=3, activation="relu",kernel_initializer="he_normal", padding="same")(x)
x = keras.layers.BatchNormalization()(x)
x = keras.layers.Conv2D(128, kernel_size=3, activation="relu",kernel_initializer="he_normal", padding="same")(x)
# x = keras.layers.BatchNormalization()(x)
# x = keras.layers.Conv2D(128, kernel_size=3, activation="relu",kernel_initializer="he_normal", padding="same")(x)
shortcut = keras.layers.Conv2D(128, kernel_size=3, activation="relu",kernel_initializer="he_normal", padding="same")(shortcut)
x = keras.layers.Add()([x, shortcut])
x = keras.layers.BatchNormalization()(x)
x = keras.layers.MaxPool2D(2)(x)

x = keras.layers.Dropout(dr_ratio)(x)


x = keras.layers.GlobalAveragePooling2D()(x)
Output = keras.layers.Dense(4, activation="softmax")(x)

model = keras.models.Model(inputs = Input, outputs = Output)
model.compile(loss="categorical_crossentropy",
optimizer=keras.optimizers.Adam(learning_rate=0.001), metrics=["accuracy"])

history=model.fit(X_train, y_train, validation_data=(X_test, y_test),callbacks=[es, reduce_lr],epochs = 100)
print("Train: ", model.evaluate(X_train, y_train))
print("Valid: ", model.evaluate(X_test, y_test))
# Out:
# Epoch 1/100
# 171/171 [==============================] - 4s 14ms/step - loss: 0.8848 - accuracy: 0.6130 - val_loss: 10.2770 - val_accuracy: 0.1835
# Epoch 2/100
# 171/171 [==============================] - 2s 12ms/step - loss: 0.6602 - accuracy: 0.7236 - val_loss: 4.9144 - val_accuracy: 0.2324
# Epoch 3/100
# 171/171 [==============================] - 2s 12ms/step - loss: 0.5420 - accuracy: 0.7722 - val_loss: 2.2591 - val_accuracy: 0.4055
# Epoch 4/100
# 171/171 [==============================] - 2s 13ms/step - loss: 0.4537 - accuracy: 0.8165 - val_loss: 0.7795 - val_accuracy: 0.7319
# Epoch 5/100
# 171/171 [==============================] - 2s 12ms/step - loss: 0.3676 - accuracy: 0.8474 - val_loss: 0.7772 - val_accuracy: 0.7110
# Epoch 6/100
# 171/171 [==============================] - 2s 12ms/step - loss: 0.2974 - accuracy: 0.8864 - val_loss: 2.0202 - val_accuracy: 0.5236
# Epoch 7/100
# 171/171 [==============================] - 2s 12ms/step - loss: 0.2542 - accuracy: 0.9062 - val_loss: 1.2344 - val_accuracy: 0.6610
# Epoch 8/100
# 171/171 [==============================] - 2s 13ms/step - loss: 0.2273 - accuracy: 0.9192 - val_loss: 0.8294 - val_accuracy: 0.7582
#
# Epoch 00008: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 9/100
# 171/171 [==============================] - 2s 13ms/step - loss: 0.1759 - accuracy: 0.9377 - val_loss: 0.3072 - val_accuracy: 0.9000
# Epoch 10/100
# 171/171 [==============================] - 2s 13ms/step - loss: 0.1580 - accuracy: 0.9436 - val_loss: 0.4223 - val_accuracy: 0.8703
# Epoch 11/100
# 171/171 [==============================] - 2s 12ms/step - loss: 0.1417 - accuracy: 0.9493 - val_loss: 0.1675 - val_accuracy: 0.9385
# Epoch 12/100
# 171/171 [==============================] - 2s 13ms/step - loss: 0.1263 - accuracy: 0.9524 - val_loss: 0.9323 - val_accuracy: 0.7802
# Epoch 13/100
# 171/171 [==============================] - 2s 12ms/step - loss: 0.1187 - accuracy: 0.9573 - val_loss: 0.2089 - val_accuracy: 0.9357
# Epoch 14/100
# 171/171 [==============================] - 2s 12ms/step - loss: 0.1105 - accuracy: 0.9601 - val_loss: 0.1925 - val_accuracy: 0.9379
#
# Epoch 00014: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Epoch 15/100
# 171/171 [==============================] - 2s 12ms/step - loss: 0.0884 - accuracy: 0.9703 - val_loss: 0.1827 - val_accuracy: 0.9418
# Epoch 16/100
# 171/171 [==============================] - 2s 12ms/step - loss: 0.0824 - accuracy: 0.9718 - val_loss: 0.1831 - val_accuracy: 0.9451
# Epoch 17/100
# 171/171 [==============================] - 2s 12ms/step - loss: 0.0794 - accuracy: 0.9734 - val_loss: 0.2459 - val_accuracy: 0.9302
#
# Epoch 00017: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# Epoch 18/100
# 171/171 [==============================] - 2s 12ms/step - loss: 0.0717 - accuracy: 0.9742 - val_loss: 0.1419 - val_accuracy: 0.9522
# Epoch 19/100
# 171/171 [==============================] - 2s 12ms/step - loss: 0.0658 - accuracy: 0.9773 - val_loss: 0.2228 - val_accuracy: 0.9363
# Epoch 20/100
# 171/171 [==============================] - 2s 12ms/step - loss: 0.0650 - accuracy: 0.9753 - val_loss: 0.1462 - val_accuracy: 0.9588
# Epoch 21/100
# 171/171 [==============================] - 2s 12ms/step - loss: 0.0592 - accuracy: 0.9802 - val_loss: 0.1929 - val_accuracy: 0.9451
#
# Epoch 00021: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# Epoch 22/100
# 171/171 [==============================] - 2s 13ms/step - loss: 0.0562 - accuracy: 0.9817 - val_loss: 0.2113 - val_accuracy: 0.9418
# Epoch 23/100
# 171/171 [==============================] - 2s 14ms/step - loss: 0.0554 - accuracy: 0.9788 - val_loss: 0.1508 - val_accuracy: 0.9588
# Epoch 24/100
# 171/171 [==============================] - 2s 14ms/step - loss: 0.0610 - accuracy: 0.9793 - val_loss: 0.1661 - val_accuracy: 0.9522
#
# Epoch 00024: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# Epoch 25/100
# 171/171 [==============================] - 2s 12ms/step - loss: 0.0523 - accuracy: 0.9828 - val_loss: 0.1588 - val_accuracy: 0.9533
# Epoch 26/100
# 171/171 [==============================] - 2s 12ms/step - loss: 0.0497 - accuracy: 0.9841 - val_loss: 0.1767 - val_accuracy: 0.9511
# Epoch 27/100
# 171/171 [==============================] - 2s 12ms/step - loss: 0.0505 - accuracy: 0.9826 - val_loss: 0.1600 - val_accuracy: 0.9544
#
# Epoch 00027: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# Epoch 28/100
# 171/171 [==============================] - 2s 13ms/step - loss: 0.0512 - accuracy: 0.9826 - val_loss: 0.1861 - val_accuracy: 0.9500
# Epoch 29/100
# 171/171 [==============================] - 2s 12ms/step - loss: 0.0466 - accuracy: 0.9850 - val_loss: 0.1592 - val_accuracy: 0.9527
# Epoch 30/100
# 171/171 [==============================] - 2s 13ms/step - loss: 0.0447 - accuracy: 0.9859 - val_loss: 0.1679 - val_accuracy: 0.9511
#
# Epoch 00030: ReduceLROnPlateau reducing learning rate to 1e-05.
# 171/171 [==============================] - 1s 5ms/step - loss: 0.0377 - accuracy: 0.9859
# Train:  [0.03774780035018921, 0.985897421836853]
# 57/57 [==============================] - 0s 5ms/step - loss: 0.1679 - accuracy: 0.9511
# Valid:  [0.16787667572498322, 0.9510989189147949]

# %% [markdown]
# ##  Save history list

# %%
hist_list = []
for i in range(3):
    hist_list.append(history_list[1].history)
joblib.dump(hist_list, "history_list.pkl")
# Out:
# ['history_list.pkl']

# %%
plt.figure(figsize=(14, 10))
for i,k in enumerate(["Crop", "Flip", "Flip and Bright"]):
    plt.ylim(0.0, 1)
    plt.plot(history_list[i].history["val_accuracy"], label=str(k))
plt.plot(history.history["val_accuracy"], label="Original")
plt.legend(loc="lower right")

# %%
history_list[1].history["val_accuracy"]
# Out:
# [0.8269230723381042,
#  0.898901104927063,
#  0.9653846025466919,
#  0.75,
#  0.9005494713783264,
#  0.9208791255950928,
#  0.9736263751983643,
#  0.9439560174942017,
#  0.9796703457832336,
#  0.8406593203544617,
#  0.9615384340286255,
#  0.658791184425354,
#  0.9950549602508545,
#  0.9950549602508545,
#  0.9884615540504456,
#  0.9873626232147217,
#  0.995604395866394,
#  0.9961538314819336,
#  0.9967032670974731,
#  0.995604395866394,
#  0.9961538314819336,
#  0.9884615540504456,
#  0.9967032670974731,
#  0.9972527623176575,
#  0.9967032670974731,
#  0.9961538314819336,
#  0.9950549602508545,
#  0.9972527623176575,
#  0.9967032670974731,
#  0.9967032670974731,
#  0.9972527623176575,
#  0.9967032670974731,
#  0.9972527623176575,
#  0.9967032670974731]

# %%
history_list[2].history["val_accuracy"]
# Out:
# [0.9038461446762085,
#  0.8181318640708923,
#  0.9582417607307434,
#  0.9576923251152039,
#  0.9796703457832336,
#  0.9873626232147217,
#  0.9538461565971375,
#  0.9489011168479919,
#  0.9692307710647583,
#  0.9862637519836426,
#  0.9549450278282166,
#  0.9901098608970642,
#  0.9840659499168396,
#  0.9851648211479187,
#  0.9719780087471008,
#  0.9906593561172485,
#  0.9901098608970642,
#  0.9928571581840515,
#  0.9945054650306702,
#  0.9912087917327881,
#  0.9890109896659851,
#  0.9950549602508545,
#  0.9950549602508545,
#  0.9950549602508545,
#  0.9890109896659851,
#  0.9945054650306702,
#  0.9961538314819336,
#  0.9967032670974731,
#  0.9939560294151306,
#  0.9967032670974731,
#  0.9967032670974731,
#  0.997802197933197,
#  0.9928571581840515,
#  0.9890109896659851,
#  0.995604395866394,
#  0.9934065937995911,
#  0.9961538314819336,
#  0.9950549602508545,
#  0.9961538314819336,
#  0.9950549602508545,
#  0.9950549602508545,
#  0.995604395866394]

# %%
history_list_2=[]

for i in [transform_crop, transform_fiip, transform_flip_bright]:
    X_train_, y_train_ = make_train_data(i)
    y_train_ = y_train_.reshape(-1, 1)
    y_train_ = encoder.transform(y_train_)
    
    dr_ratio=0.4

    Input = keras.layers.Input(shape=X_train_[0].shape)

    x = keras.layers.Conv2D(16, kernel_size=3, activation="relu",kernel_initializer="he_normal", padding="same")(Input)
    x = keras.layers.BatchNormalization()(x)
    x = keras.layers.MaxPool2D(2)(x)

    x = keras.layers.Dropout(dr_ratio)(x)

    shortcut =x
    x = keras.layers.Conv2D(32, kernel_size=3, activation="relu",kernel_initializer="he_normal", padding="same")(x)
    x = keras.layers.BatchNormalization()(x)
    x = keras.layers.Conv2D(32, kernel_size=3, activation="relu",kernel_initializer="he_normal", padding="same")(x)
    # x = keras.layers.BatchNormalization()(x)
    # x = keras.layers.Conv2D(32, kernel_size=3, activation="relu",kernel_initializer="he_normal", padding="same")(x)
    shortcut = keras.layers.Conv2D(32, kernel_size=5, activation="relu",kernel_initializer="he_normal", padding="same")(shortcut)
    x = keras.layers.Add()([x, shortcut])
    x   = keras.layers.BatchNormalization()(x)
    x = keras.layers.MaxPool2D(2)(x)


    x = keras.layers.Dropout(dr_ratio)(x)


    shortcut =x
    x = keras.layers.Conv2D(64, kernel_size=3, activation="relu",kernel_initializer="he_normal", padding="same")(x)
    x = keras.layers.BatchNormalization()(x)
    x = keras.layers.Conv2D(64, kernel_size=3, activation="relu",kernel_initializer="he_normal", padding="same")(x)
    # x = keras.layers.BatchNormalization()(x)
    # x = keras.layers.Conv2D(64, kernel_size=3, activation="relu",kernel_initializer="he_normal", padding="same")(x)
    shortcut = keras.layers.Conv2D(64, kernel_size=3, activation="relu",kernel_initializer="he_normal", padding="same")(shortcut)
    x = keras.layers.Add()([x, shortcut])
    x = keras.layers.BatchNormalization()(x)
    x = keras.layers.MaxPool2D(2)(x)

    x = keras.layers.Dropout(dr_ratio)(x)

    shortcut =x
    x = keras.layers.Conv2D(128, kernel_size=3, activation="relu",kernel_initializer="he_normal", padding="same")(x)
    x = keras.layers.BatchNormalization()(x)
    x = keras.layers.Conv2D(128, kernel_size=3, activation="relu",kernel_initializer="he_normal", padding="same")(x)
    # x = keras.layers.BatchNormalization()(x)
    # x = keras.layers.Conv2D(128, kernel_size=3, activation="relu",kernel_initializer="he_normal", padding="same")(x)
    shortcut = keras.layers.Conv2D(128, kernel_size=3, activation="relu",kernel_initializer="he_normal", padding="same")(shortcut)
    x = keras.layers.Add()([x, shortcut])
    x = keras.layers.BatchNormalization()(x)
    x = keras.layers.MaxPool2D(2)(x)

    x = keras.layers.Dropout(dr_ratio)(x)


    x = keras.layers.GlobalAveragePooling2D()(x)
    Output = keras.layers.Dense(4, activation="softmax")(x)

    model = keras.models.Model(inputs = Input, outputs = Output)
    model.compile(loss="categorical_crossentropy",
    optimizer=keras.optimizers.Adam(learning_rate=0.001), metrics=["accuracy"])

    history_list_2.append(model.fit(X_train_, y_train_, validation_data=(X_test, y_test),callbacks=[es, reduce_lr],epochs = 100))
    print("Train: ", model.evaluate(X_train_, y_train_))
    print("Valid: ", model.evaluate(X_test, y_test))
# Out:
# ---------------------------------------------------------------------------
# InternalError                             Traceback (most recent call last)
# Input In [73], in <cell line: 3>()
#      63 model = keras.models.Model(inputs = Input, outputs = Output)
#      64 model.compile(loss="categorical_crossentropy",
#      65 optimizer=keras.optimizers.Adam(learning_rate=0.001), metrics=["accuracy"])
# ---> 67 history_list_2.append(model.fit(X_train_, y_train_, validation_data=(X_test, y_test),callbacks=[es, reduce_lr],epochs = 100))
#      68 print("Train: ", model.evaluate(X_train_, y_train_))
#      69 print("Valid: ", model.evaluate(X_test, y_test))
#
# File ~\anaconda3\envs\python3.9.0\lib\site-packages\tensorflow\python\keras\engine\training.py:1139, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1133   self._cluster_coordinator = cluster_coordinator.ClusterCoordinator(
#    1134       self.distribute_strategy)
#    1136 with self.distribute_strategy.scope(), \
#    1137      training_utils.RespectCompiledTrainableState(self):
#    1138   # Creates a `tf.data.Dataset` and handles batch and epoch iteration.
# -> 1139   data_handler = data_adapter.get_data_handler(
#    1140       x=x,
#    1141       y=y,
#    1142       sample_weight=sample_weight,
#    1143       batch_size=batch_size,
#    1144       steps_per_epoch=steps_per_epoch,
#    1145       initial_epoch=initial_epoch,
#    1146       epochs=epochs,
#    1147       shuffle=shuffle,
#    1148       class_weight=class_weight,
#    1149       max_queue_size=max_queue_size,
#    1150       workers=workers,
#    1151       use_multiprocessing=use_multiprocessing,
#    1152       model=self,
#    1153       steps_per_execution=self._steps_per_execution)
#    1155   # Container that configures and calls `tf.keras.Callback`s.
#    1156   if not isinstance(callbacks, callbacks_module.CallbackList):
#
# File ~\anaconda3\envs\python3.9.0\lib\site-packages\tensorflow\python\keras\engine\data_adapter.py:1394, in get_data_handler(*args, **kwargs)
#    1392 if getattr(kwargs["model"], "_cluster_coordinator", None):
#    1393   return _ClusterCoordinatorDataHandler(*args, **kwargs)
# -> 1394 return DataHandler(*args, **kwargs)
#
# File ~\anaconda3\envs\python3.9.0\lib\site-packages\tensorflow\python\keras\engine\data_adapter.py:1149, in DataHandler.__init__(self, x, y, sample_weight, batch_size, steps_per_epoch, initial_epoch, epochs, shuffle, class_weight, max_queue_size, workers, use_multiprocessing, model, steps_per_execution, distribute)
#    1146   self._steps_per_execution_value = steps_per_execution.numpy().item()
#    1148 adapter_cls = select_data_adapter(x, y)
# -> 1149 self._adapter = adapter_cls(
#    1150     x,
#    1151     y,
#    1152     batch_size=batch_size,
#    1153     steps=steps_per_epoch,
#    1154     epochs=epochs - initial_epoch,
#    1155     sample_weights=sample_weight,
#    1156     shuffle=shuffle,
#    1157     max_queue_size=max_queue_size,
#    1158     workers=workers,
#    1159     use_multiprocessing=use_multiprocessing,
#    1160     distribution_strategy=ds_context.get_strategy(),
#    1161     model=model)
#    1163 strategy = ds_context.get_strategy()
#    1165 self._current_step = 0
#
# File ~\anaconda3\envs\python3.9.0\lib\site-packages\tensorflow\python\keras\engine\data_adapter.py:243, in TensorLikeDataAdapter.__init__(self, x, y, sample_weights, sample_weight_modes, batch_size, epochs, steps, shuffle, **kwargs)
#     232 def __init__(self,
#     233              x,
#     234              y=None,
#    (...)
#     240              shuffle=False,
#     241              **kwargs):
#     242   super(TensorLikeDataAdapter, self).__init__(x, y, **kwargs)
# --> 243   x, y, sample_weights = _process_tensorlike((x, y, sample_weights))
#     244   sample_weight_modes = broadcast_sample_weight_modes(
#     245       sample_weights, sample_weight_modes)
#     247   # If sample_weights are not specified for an output use 1.0 as weights.
#
# File ~\anaconda3\envs\python3.9.0\lib\site-packages\tensorflow\python\keras\engine\data_adapter.py:1042, in _process_tensorlike(inputs)
#    1039     return _scipy_sparse_to_sparse_tensor(x)
#    1040   return x
# -> 1042 inputs = nest.map_structure(_convert_numpy_and_scipy, inputs)
#    1043 return nest.list_to_tuple(inputs)
#
# File ~\anaconda3\envs\python3.9.0\lib\site-packages\tensorflow\python\util\nest.py:869, in map_structure(func, *structure, **kwargs)
#     865 flat_structure = (flatten(s, expand_composites) for s in structure)
#     866 entries = zip(*flat_structure)
#     868 return pack_sequence_as(
# --> 869     structure[0], [func(*x) for x in entries],
#     870     expand_composites=expand_composites)
#
# File ~\anaconda3\envs\python3.9.0\lib\site-packages\tensorflow\python\util\nest.py:869, in <listcomp>(.0)
#     865 flat_structure = (flatten(s, expand_composites) for s in structure)
#     866 entries = zip(*flat_structure)
#     868 return pack_sequence_as(
# --> 869     structure[0], [func(*x) for x in entries],
#     870     expand_composites=expand_composites)
#
# File ~\anaconda3\envs\python3.9.0\lib\site-packages\tensorflow\python\keras\engine\data_adapter.py:1037, in _process_tensorlike.<locals>._convert_numpy_and_scipy(x)
#    1035   if issubclass(x.dtype.type, np.floating):
#    1036     dtype = backend.floatx()
# -> 1037   return ops.convert_to_tensor_v2_with_dispatch(x, dtype=dtype)
#    1038 elif _is_scipy_sparse(x):
#    1039   return _scipy_sparse_to_sparse_tensor(x)
#
# File ~\anaconda3\envs\python3.9.0\lib\site-packages\tensorflow\python\util\traceback_utils.py:153, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
# --> 153   raise e.with_traceback(filtered_tb) from None
#     154 finally:
#     155   del filtered_tb
#
# File ~\anaconda3\envs\python3.9.0\lib\site-packages\tensorflow\python\framework\constant_op.py:106, in convert_to_eager_tensor(value, ctx, dtype)
#     104     dtype = dtypes.as_dtype(dtype).as_datatype_enum
#     105 ctx.ensure_initialized()
# --> 106 return ops.EagerTensor(value, ctx.device_name, dtype)
#
# InternalError: Failed copying input tensor from /job:localhost/replica:0/task:0/device:CPU:0 to /job:localhost/replica:0/task:0/device:GPU:0 in order to run _EagerConst: Dst tensor is not initialized.

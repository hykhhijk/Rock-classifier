# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
import tensorflow.keras as keras
import cv2
import joblib
from sklearn.preprocessing import OneHotEncoder
from sklearn.model_selection import train_test_split
import albumentations as A
import time
from sklearn.model_selection import StratifiedKFold

# %%
X = joblib.load("converted_img.pkl")
y = joblib.load("label.pkl")

# %% [markdown]
# To pass an image to the augmentation pipeline you need to call the transform function created by a call to A.Compose at Step 2. In the image argument to that function, you need to pass an image that you want to augment.

# %%
fig = plt.figure(figsize=(14, 10))
for i in range(1, 17):
    ax = plt.subplot(4, 4, i)
    ax.axes.xaxis.set_visible(False)
    ax.axes.yaxis.set_visible(False)
    plt.imshow(X[i])

# %%
X = np.float32(X)

# %%
encoder = OneHotEncoder(sparse=False)
encoder.fit(y.reshape(-1, 1))
# Out:
# OneHotEncoder(sparse=False)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=y, shuffle=True)
y_test = encoder.transform(y_test.reshape(-1, 1))
# y_train = encoder.transform(y_train.reshape(-1, 1))

test_trainsform = A.Compose([
A.Resize(32, 32)
])

img_list=[]
for i in range(len(X_test)):
    img_list.append(test_trainsform(image=X_test[i])["image"])
img_list = np.float32(img_list)
X_test = img_list

# %%
transform_crop = A.Compose([
    A.Resize(40, 40),
    A.RandomCrop(32, 32),
    A.OneOf([
    A.HorizontalFlip(p=1), 
    A.VerticalFlip(p=1)],p=1)
])

# %%
transform_flip_bright = A.Compose([
    A.Resize(32, 32),
    A.HorizontalFlip(p=0.5), 
    A.VerticalFlip(p=0.5),
    A.RandomBrightness(p=0.5, limit=(-0.25, 0.25))
])
# Out:
# C:\Users\hjhhi\anaconda3\envs\python3.9.0\lib\site-packages\albumentations\augmentations\transforms.py:1800: FutureWarning: This class has been deprecated. Please use RandomBrightnessContrast
#   warnings.warn(

# %%
transform_fiip = A.Compose([
    A.Resize(32, 32),
    A.HorizontalFlip(p=0.5), 
    A.VerticalFlip(p=0.5),
])

# %%
temp=[]
for _ in range(8):
    temp.append(transform_crop(image=X_train[0])["image"])

# %%
fig = plt.figure(figsize=(14, 10))
for i in range(1, 9):
    ax = plt.subplot(2, 4, i)
    ax.axes.xaxis.set_visible(False)
    ax.axes.yaxis.set_visible(False)
    plt.imshow(temp[i-1])

# %%
temp=[]
for _ in range(8):
    temp.append(transform_fiip(image=X_train[0])["image"])

# %%
fig = plt.figure(figsize=(14, 10))
for i in range(1, 9):
    ax = plt.subplot(2, 4, i)
    ax.axes.xaxis.set_visible(False)
    ax.axes.yaxis.set_visible(False)
    plt.imshow(temp[i-1])

# %%
temp=[]
for _ in range(8):
    temp.append(transform_flip_bright(image=X_train[0])["image"])

# %%
fig = plt.figure(figsize=(14, 10))
for i in range(1, 9):
    ax = plt.subplot(2, 4, i)
    ax.axes.xaxis.set_visible(False)
    ax.axes.yaxis.set_visible(False)
    plt.imshow(temp[i-1])

# %%
plt.imshow(X_train[0])

# %%
def make_train_data(augment):
    img_list = []
    label_list = []
    for _ in range(10):
        for i in range(len(X_train)):
            img_list.append(augment(image=X_train[i])["image"])
            label_list.append(y_train[i])
    img_list = np.float32(img_list)
    img_list = img_list.reshape(-1, 32, 32, 3)
    label_list = np.float32(label_list)
    return [img_list, label_list]

# %% [markdown]
# # Augmentation model

# %%
es = keras.callbacks.EarlyStopping(monitor="val_accuracy", patience=10, mode="max")

# %%
reduce_lr = keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.5,patience=3, min_lr=0.00001, verbose=1)

# %%
history_list=[]

for i in [transform_crop, transform_fiip, transform_flip_bright]:
    X_train_, y_train_ = make_train_data(i)
    y_train_ = y_train_.reshape(-1, 1)
    y_train_ = encoder.transform(y_train_)
    
    dr_ratio=0.2

    Input = keras.layers.Input(shape=X_train_[0].shape)

    x = keras.layers.Conv2D(16, kernel_size=3, activation="relu",kernel_initializer="he_normal", padding="same")(Input)
    x = keras.layers.BatchNormalization()(x)
    x = keras.layers.MaxPool2D(2)(x)

    x = keras.layers.Dropout(dr_ratio)(x)

    shortcut =x
    x = keras.layers.Conv2D(32, kernel_size=3, activation="relu",kernel_initializer="he_normal", padding="same")(x)
    x = keras.layers.BatchNormalization()(x)
    x = keras.layers.Conv2D(32, kernel_size=3, activation="relu",kernel_initializer="he_normal", padding="same")(x)
    # x = keras.layers.BatchNormalization()(x)
    # x = keras.layers.Conv2D(32, kernel_size=3, activation="relu",kernel_initializer="he_normal", padding="same")(x)
    shortcut = keras.layers.Conv2D(32, kernel_size=5, activation="relu",kernel_initializer="he_normal", padding="same")(shortcut)
    x = keras.layers.Add()([x, shortcut])
    x   = keras.layers.BatchNormalization()(x)
    x = keras.layers.MaxPool2D(2)(x)


    x = keras.layers.Dropout(dr_ratio)(x)


    shortcut =x
    x = keras.layers.Conv2D(64, kernel_size=3, activation="relu",kernel_initializer="he_normal", padding="same")(x)
    x = keras.layers.BatchNormalization()(x)
    x = keras.layers.Conv2D(64, kernel_size=3, activation="relu",kernel_initializer="he_normal", padding="same")(x)
    # x = keras.layers.BatchNormalization()(x)
    # x = keras.layers.Conv2D(64, kernel_size=3, activation="relu",kernel_initializer="he_normal", padding="same")(x)
    shortcut = keras.layers.Conv2D(64, kernel_size=3, activation="relu",kernel_initializer="he_normal", padding="same")(shortcut)
    x = keras.layers.Add()([x, shortcut])
    x = keras.layers.BatchNormalization()(x)
    x = keras.layers.MaxPool2D(2)(x)

    x = keras.layers.Dropout(dr_ratio)(x)

    shortcut =x
    x = keras.layers.Conv2D(128, kernel_size=3, activation="relu",kernel_initializer="he_normal", padding="same")(x)
    x = keras.layers.BatchNormalization()(x)
    x = keras.layers.Conv2D(128, kernel_size=3, activation="relu",kernel_initializer="he_normal", padding="same")(x)
    # x = keras.layers.BatchNormalization()(x)
    # x = keras.layers.Conv2D(128, kernel_size=3, activation="relu",kernel_initializer="he_normal", padding="same")(x)
    shortcut = keras.layers.Conv2D(128, kernel_size=3, activation="relu",kernel_initializer="he_normal", padding="same")(shortcut)
    x = keras.layers.Add()([x, shortcut])
    x = keras.layers.BatchNormalization()(x)
    x = keras.layers.MaxPool2D(2)(x)

    x = keras.layers.Dropout(dr_ratio)(x)


    x = keras.layers.GlobalAveragePooling2D()(x)
    Output = keras.layers.Dense(4, activation="softmax")(x)

    model = keras.models.Model(inputs = Input, outputs = Output)
    model.compile(loss="categorical_crossentropy",
    optimizer=keras.optimizers.Adam(learning_rate=0.001), metrics=["accuracy"])

    history_list.append(model.fit(X_train_, y_train_, validation_data=(X_test, y_test),callbacks=[es, reduce_lr],epochs = 100))
    print("Train: ", model.evaluate(X_train_, y_train_))
    print("Valid: ", model.evaluate(X_test, y_test))
# Out:
# Epoch 1/100
# 1707/1707 [==============================] - 22s 12ms/step - loss: 0.4729 - accuracy: 0.8079 - val_loss: 5.2093 - val_accuracy: 0.3973
# Epoch 2/100
# 1707/1707 [==============================] - 20s 12ms/step - loss: 0.2166 - accuracy: 0.9171 - val_loss: 2.1435 - val_accuracy: 0.5896
# Epoch 3/100
# 1707/1707 [==============================] - 20s 12ms/step - loss: 0.1506 - accuracy: 0.9439 - val_loss: 2.5714 - val_accuracy: 0.5308
# Epoch 4/100
# 1707/1707 [==============================] - 20s 12ms/step - loss: 0.1129 - accuracy: 0.9586 - val_loss: 2.2028 - val_accuracy: 0.5533
# Epoch 5/100
# 1707/1707 [==============================] - 20s 12ms/step - loss: 0.0912 - accuracy: 0.9669 - val_loss: 3.3970 - val_accuracy: 0.5126
#
# Epoch 00005: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch
ms/step - loss: 0.0028 - accuracy: 0.9992 - val_loss: 0.0198 - val_accuracy: 0.9951
# Epoch 27/100
# 1707/1707 [==============================] - 24s 14ms/step - loss: 0.0028 - accuracy: 0.9993 - val_loss: 0.0185 - val_accuracy: 0.9951
# Epoch 28/100
# 1707/1707 [==============================] - 23s 14ms/step - loss: 0.0034 - accuracy: 0.9989 - val_loss: 0.0217 - val_accuracy: 0.9945
#
# Epoch 00028: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# Epoch 29/100
# 1707/1707 [==============================] - 23s 14ms/step - loss: 0.0025 - accuracy: 0.9992 - val_loss: 0.0214 - val_accuracy: 0.9951
# Epoch 30/100
# 1707/1707 [==============================] - 23s 13ms/step - loss: 0.0022 - accuracy: 0.9992 - val_loss: 0.0244 - val_accuracy: 0.9929
# Epoch 31/100
# 1707/1707 [==============================] - 23s 13ms/step - loss: 0.0021 - accuracy: 0.9993 - val_loss: 0.0181 - val_accuracy: 0.9945
#
# Epoch 00031: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# Epoch 32/100
# 1707/1707 [==============================] - 23s 13ms/step - loss: 0.0017 - accuracy: 0.9995 - val_loss: 0.0207 - val_accuracy: 0.9940
# Epoch 33/100
# 1707/1707 [==============================] - 24s 14ms/step - loss: 0.0016 - accuracy: 0.9996 - val_loss: 0.0200 - val_accuracy: 0.9951
# Epoch 34/100
# 1707/1707 [==============================] - 23s 14ms/step - loss: 0.0018 - accuracy: 0.9994 - val_loss: 0.0191 - val_accuracy: 0.9945
#
# Epoch 00034: ReduceLROnPlateau reducing learning rate to 1e-05.
# Epoch 35/100
# 1707/1707 [==============================] - 23s 13ms/step - loss: 0.0015 - accuracy: 0.9996 - val_loss: 0.0203 - val_accuracy: 0.9951
# 1707/1707 [==============================] - 9s 5ms/step - loss: 8.2042e-05 - accuracy: 1.0000
# Train:  [8.204196637962013e-05, 0.999981701374054]
# 57/57 [==============================] - 0s 5ms/step - loss: 0.0203 - accuracy: 0.9951
# Valid:  [0.02031893841922283, 0.9950549602508545]

# %%
plt.figure(figsize=(14, 10))
for i,k in enumerate(["Crop", "Flip", "Flip and Bright"]):
    plt.ylim(0.0, 1)
    plt.plot(history_list[i].history["val_accuracy"], label=str(k))
plt.legend(loc="lower right")

# %% [markdown]
# # Original data model

# %%
X = joblib.load("CV2_float32.pkl")

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=y, shuffle=True)

# %%
y_train = encoder.transform(y_train.reshape(-1, 1))
y_test = encoder.transform(y_test.reshape(-1, 1))

# %%
dr_ratio=0.2

Input = keras.layers.Input(shape=X_train[0].shape)

x = keras.layers.Conv2D(16, kernel_size=3, activation="relu",kernel_initializer="he_normal", padding="same")(Input)
x = keras.layers.BatchNormalization()(x)
x = keras.layers.MaxPool2D(2)(x)

x = keras.layers.Dropout(dr_ratio)(x)

shortcut =x
x = keras.layers.Conv2D(32, kernel_size=3, activation="relu",kernel_initializer="he_normal", padding="same")(x)
x = keras.layers.BatchNormalization()(x)
x = keras.layers.Conv2D(32, kernel_size=3, activation="relu",kernel_initializer="he_normal", padding="same")(x)
# x = keras.layers.BatchNormalization()(x)
# x = keras.layers.Conv2D(32, kernel_size=3, activation="relu",kernel_initializer="he_normal", padding="same")(x)
shortcut = keras.layers.Conv2D(32, kernel_size=5, activation="relu",kernel_initializer="he_normal", padding="same")(shortcut)
x = keras.layers.Add()([x, shortcut])
x   = keras.layers.BatchNormalization()(x)
x = keras.layers.MaxPool2D(2)(x)


x = keras.layers.Dropout(dr_ratio)(x)


shortcut =x
x = keras.layers.Conv2D(64, kernel_size=3, activation="relu",kernel_initializer="he_normal", padding="same")(x)
x = keras.layers.BatchNormalization()(x)
x = keras.layers.Conv2D(64, kernel_size=3, activation="relu",kernel_initializer="he_normal", padding="same")(x)
# x = keras.layers.BatchNormalization()(x)
# x = keras.layers.Conv2D(64, kernel_size=3, activation="relu",kernel_initializer="he_normal", padding="same")(x)
shortcut = keras.layers.Conv2D(64, kernel_size=3, activation="relu",kernel_initializer="he_normal", padding="same")(shortcut)
x = keras.layers.Add()([x, shortcut])
x = keras.layers.BatchNormalization()(x)
x = keras.layers.MaxPool2D(2)(x)

x = keras.layers.Dropout(dr_ratio)(x)

shortcut =x
x = keras.layers.Conv2D(128, kernel_size=3, activation="relu",kernel_initializer="he_normal", padding="same")(x)
x = keras.layers.BatchNormalization()(x)
x = keras.layers.Conv2D(128, kernel_size=3, activation="relu",kernel_initializer="he_normal", padding="same")(x)
# x = keras.layers.BatchNormalization()(x)
# x = keras.layers.Conv2D(128, kernel_size=3, activation="relu",kernel_initializer="he_normal", padding="same")(x)
shortcut = keras.layers.Conv2D(128, kernel_size=3, activation="relu",kernel_initializer="he_normal", padding="same")(shortcut)
x = keras.layers.Add()([x, shortcut])
x = keras.layers.BatchNormalization()(x)
x = keras.layers.MaxPool2D(2)(x)

x = keras.layers.Dropout(dr_ratio)(x)


x = keras.layers.GlobalAveragePooling2D()(x)
Output = keras.layers.Dense(4, activation="softmax")(x)

model = keras.models.Model(inputs = Input, outputs = Output)
model.compile(loss="categorical_crossentropy",
optimizer=keras.optimizers.Adam(learning_rate=0.001), metrics=["accuracy"])

history=model.fit(X_train, y_train, validation_data=(X_test, y_test),callbacks=[es, reduce_lr],epochs = 100)
print("Train: ", model.evaluate(X_train, y_train))
print("Valid: ", model.evaluate(X_test, y_test))
# Out:
# Epoch 1/100
# 171/171 [==============================] - 4s 14ms/step - loss: 0.8848 - accuracy: 0.6130 - val_loss: 10.2770 - val_accuracy: 0.1835
# Epoch 2/100
# 171/171 [==============================] - 2s 12ms/step - loss: 0.6602 - accuracy: 0.7236 - val_loss: 4.9144 - val_accuracy: 0.2324
# Epoch 3/100
# 171/171 [==============================] - 2s 12ms/step - loss: 0.5420 - accuracy: 0.7722 - val_loss: 2.2591 - val_accuracy: 0.4055
# Epoch 4/100
# 171/171 [==============================] - 2s 13ms/step - loss: 0.4537 - accuracy: 0.8165 - val_loss: 0.7795 - val_accuracy: 0.7319
# Epoch 5/100
# 171/171 [==============================] - 2s 12ms/step - loss: 0.3676 - accuracy: 0.8474 - val_loss: 0.7772 - val_accuracy: 0.7110
# Epoch 6/100
# 171/171 [==============================] - 2s 12ms/step - loss: 0.2974 - accuracy: 0.8864 - val_loss: 2.0202 - val_accuracy: 0.5236
# Epoch 7/100
# 171/171 [==============================] - 2s 12ms/step - loss: 0.2542 - accuracy: 0.9062 - val_loss: 1.2344 - val_accuracy: 0.6610
# Epoch 8/100
# 171/171 [==============================] - 2s 13ms/step - loss: 0.2273 - accuracy: 0.9192 - val_loss: 0.8294 - val_accuracy: 0.7582
#
# Epoch 00008: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 9/100
# 171/171 [==============================] - 2s 13ms/step - loss: 0.1759 - accuracy: 0.9377 - val_loss: 0.3072 - val_accuracy: 0.9000
# Epoch 10/100
# 171/171 [==============================] - 2s 13ms/step - loss: 0.1580 - accuracy: 0.9436 - val_loss: 0.4223 - val_accuracy: 0.8703
# Epoch 11/100
# 171/171 [==============================] - 2s 12ms/step - loss: 0.1417 - accuracy: 0.9493 - val_loss: 0.1675 - val_accuracy: 0.9385
# Epoch 12/100
# 171/171 [==============================] - 2s 13ms/step - loss: 0.1263 - accuracy: 0.9524 - val_loss: 0.9323 - val_accuracy: 0.7802
# Epoch 13/100
# 171/171 [==============================] - 2s 12ms/step - loss: 0.1187 - accuracy: 0.9573 - val_loss: 0.2089 - val_accuracy: 0.9357
# Epoch 14/100
# 171/171 [==============================] - 2s 12ms/step - loss: 0.1105 - accuracy: 0.9601 - val_loss: 0.1925 - val_accuracy: 0.9379
#
# Epoch 00014: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Epoch 15/100
# 171/171 [==============================] - 2s 12ms/step - loss: 0.0884 - accuracy: 0.9703 - val_loss: 0.1827 - val_accuracy: 0.9418
# Epoch 16/100
# 171/171 [==============================] - 2s 12ms/step - loss: 0.0824 - accuracy: 0.9718 - val_loss: 0.1831 - val_accuracy: 0.9451
# Epoch 17/100
# 171/171 [==============================] - 2s 12ms/step - loss: 0.0794 - accuracy: 0.9734 - val_loss: 0.2459 - val_accuracy: 0.9302
#
# Epoch 00017: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# Epoch
#  0.9736263751983643,
#  0.9439560174942017,
#  0.9796703457832336,
#  0.8406593203544617,
#  0.9615384340286255,
#  0.658791184425354,
#  0.9950549602508545,
#  0.9950549602508545,
#  0.9884615540504456,
#  0.9873626232147217,
#  0.995604395866394,
#  0.9961538314819336,
#  0.9967032670974731,
#  0.995604395866394,
#  0.9961538314819336,
#  0.9884615540504456,
#  0.9967032670974731,
#  0.9972527623176575,
#  0.9967032670974731,
#  0.9961538314819336,
#  0.9950549602508545,
#  0.9972527623176575,
#  0.9967032670974731,
#  0.9967032670974731,
#  0.9972527623176575,
#  0.9967032670974731,
#  0.9972527623176575,
#  0.9967032670974731]

# %%
history_list[2].history["val_accuracy"]
# Out:
# [0.9038461446762085,
#  0.8181318640708923,
#  0.9582417607307434,
#  0.9576923251152039,
#  0.9796703457832336,
#  0.9873626232147217,
#  0.9538461565971375,
#  0.9489011168479919,
#  0.9692307710647583,
#  0.9862637519836426,
#  0.9549450278282166,
#  0.9901098608970642,
#  0.9840659499168396,
#  0.9851648211479187,
#  0.9719780087471008,
#  0.9906593561172485,
#  0.9901098608970642,
#  0.9928571581840515,
#  0.9945054650306702,
#  0.9912087917327881,
#  0.9890109896659851,
#  0.9950549602508545,
#  0.9950549602508545,
#  0.9950549602508545,
#  0.9890109896659851,
#  0.9945054650306702,
#  0.9961538314819336,
#  0.9967032670974731,
#  0.9939560294151306,
#  0.9967032670974731,
#  0.9967032670974731,
#  0.997802197933197,
#  0.9928571581840515,
#  0.9890109896659851,
#  0.995604395866394,
#  0.9934065937995911,
#  0.9961538314819336,
#  0.9950549602508545,
#  0.9961538314819336,
#  0.9950549602508545,
#  0.9950549602508545,
#  0.995604395866394]

# %%
history_list_2=[]

for i in [transform_crop, transform_fiip, transform_flip_bright]:
    X_train_, y_train_ = make_train_data(i)
    y_train_ = y_train_.reshape(-1, 1)
    y_train_ = encoder.transform(y_train_)
    
    dr_ratio=0.1

    Input = keras.layers.Input(shape=X_train_[0].shape)

    x = keras.layers.Conv2D(16, kernel_size=3, activation="relu",kernel_initializer="he_normal", padding="same")(Input)
    x = keras.layers.BatchNormalization()(x)
    x = keras.layers.MaxPool2D(2)(x)

    x = keras.layers.Dropout(dr_ratio)(x)

    shortcut =x
    x = keras.layers.Conv2D(32, kernel_size=3, activation="relu",kernel_initializer="he_normal", padding="same")(x)
    x = keras.layers.BatchNormalization()(x)
    x = keras.layers.Conv2D(32, kernel_size=3, activation="relu",kernel_initializer="he_normal", padding="same")(x)
    # x = keras.layers.BatchNormalization()(x)
    # x = keras.layers.Conv2D(32, kernel_size=3, activation="relu",kernel_initializer="he_normal", padding="same")(x)
    shortcut = keras.layers.Conv2D(32, kernel_size=5, activation="relu",kernel_initializer="he_normal", padding="same")(shortcut)
    x = keras.layers.Add()([x, shortcut])
    x   = keras.layers.BatchNormalization()(x)
    x = keras.layers.MaxPool2D(2)(x)


    x = keras.layers.Dropout(dr_ratio)(x)


    shortcut =x
    x = keras.layers.Conv2D(64, kernel_size=3, activation="relu",kernel_initializer="he_normal", padding="same")(x)
    x = keras.layers.BatchNormalization()(x)
    x = keras.layers.Conv2D(64, kernel_size=3, activation="relu",kernel_initializer="he_normal", padding="same")(x)
    # x = keras.layers.BatchNormalization()(x)
    # x = keras.layers.Conv2D(64, kernel_size=3, activation="relu",kernel_initializer="he_normal", padding="same")(x)
    shortcut = keras.layers.Conv2D(64, kernel_size=3, activation="relu",kernel_initializer="he_normal", padding="same")(shortcut)
    x = keras.layers.Add()([x, shortcut])
    x = keras.layers.BatchNormalization()(x)
    x = keras.layers.MaxPool2D(2)(x)

    x = keras.layers.Dropout(dr_ratio)(x)

    shortcut =x
    x = keras.layers.Conv2D(128, kernel_size=3, activation="relu",kernel_initializer="he_normal", padding="same")(x)
    x = keras.layers.BatchNormalization()(x)
    x = keras.layers.Conv2D(128, kernel_size=3, activation="relu",kernel_initializer="he_normal", padding="same")(x)
    # x = keras.layers.BatchNormalization()(x)
    # x = keras.layers.Conv2D(128, kernel_size=3, activation="relu",kernel_initializer="he_normal", padding="same")(x)
    shortcut = keras.layers.Conv2D(128, kernel_size=3, activation="relu",kernel_initializer="he_normal", padding="same")(shortcut)
    x = keras.layers.Add()([x, shortcut])
    x = keras.layers.BatchNormalization()(x)
    x = keras.layers.MaxPool2D(2)(x)

    x = keras.layers.Dropout(dr_ratio)(x)


    x = keras.layers.GlobalAveragePooling2D()(x)
    Output = keras.layers.Dense(4, activation="softmax")(x)

    model = keras.models.Model(inputs = Input, outputs = Output)
    model.compile(loss="categorical_crossentropy",
    optimizer=keras.optimizers.Adam(learning_rate=0.001), metrics=["accuracy"])

    history_list_2.append(model.fit(X_train_, y_train_, validation_data=(X_test, y_test),callbacks=[es, reduce_lr],epochs = 100))
    print("Train: ", model.evaluate(X_train_, y_train_))
    print("Valid: ", model.evaluate(X_test, y_test))
# Out:
# Epoch 1/100
# 1707/1707 [==============================] - 20s 11ms/step - loss: 0.3704 - accuracy: 0.8510 - val_loss: 1.3175 - val_accuracy: 0.6599
# Epoch 2/100
# 1707/1707 [==============================] - 19s 11ms/step - loss: 0.1601 - accuracy: 0.9404 - val_loss: 0.4955 - val_accuracy: 0.8434
# Epoch 3/100
# 1707/1707 [==============================] - 19s 11ms/step - loss: 0.1082 - accuracy: 0.9597 - val_loss: 0.2607 - val_accuracy: 0.9016
# Epoch 4/100
# 1707/1707 [==============================] - 19s 11ms/step - loss: 0.0797 - accuracy: 0.9703 - val_loss: 0.3974 - val_accuracy: 0.8857
# Epoch 5/100
# 1707/1707 [==============================] - 19s 11ms/step - loss: 0.0632 - accuracy: 0.9775 - val_loss: 0.5916 - val_accuracy: 0.7918
# Epoch 6/100
# 1707/1707 [==============================] - 19s 11ms/step - loss: 0.0507 - accuracy: 0.9821 - val_loss: 1.4874 - val_accuracy: 0.7176
#
# Epoch 00006: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 7/100
# 1707/1707 [==============================] - 19s 11ms/step - loss: 0.0222 - accuracy: 0.9927 - val_loss: 1.4250 - val_accuracy: 0.6945
# Epoch 8/100
# 1707/1707 [==============================] - 19s 11ms/step - loss: 0.0187 - accuracy: 0.9936 - val_loss: 0.6199 - val_accuracy: 0.8714
# Epoch 9/100
# 1707/1707 [==============================] - 19s 11ms/step - loss: 0.0188 - accuracy: 0.9934 - val_loss: 0.2719 - val_accuracy: 0.9286
#
# Epoch 00009: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Epoch 10/100
# 1707/1707 [==============================] - 19s 11ms/step - loss: 0.0083 - accuracy: 0.9974 - val_loss: 0.7091 - val_accuracy: 0.8714
# Epoch 11/100
# 1707/1707 [==============================] - 18s 11ms/step - loss: 0.0074 - accuracy: 0.9975 - val_loss: 0.2342 - val_accuracy: 0.9319
# Epoch 12/100
# 1707/1707 [==============================] - 18s 11ms/step - loss: 0.0082 - accuracy: 0.9973 - val_loss: 0.5573 - val_accuracy: 0.8698
# Epoch 13/100
# 1707/1707 [==============================] - 18s 11ms/step - loss: 0.0059 - accuracy: 0.9982 - val_loss: 0.5525 - val_accuracy: 0.8769
# Epoch 14/100
# 1707/1707 [==============================] - 18s 11ms/step - loss: 0.0072 - accuracy: 0.9978 - val_loss: 0.4306 - val_accuracy: 0.8978
#
# Epoch 00014: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# Epoch 15/100
# 1707/1707 [==============================] - 19s 11ms/step - loss: 0.0035 - accuracy: 0.9989 - val_loss: 0.4768 - val_accuracy: 0.8956
# Epoch 16/100
# 1707/1707 [==============================] - 18s 11ms/step - loss: 0.0031 - accuracy: 0.9991 - val_loss: 0.3664 - val_accuracy: 0.9225
# Epoch 17/100
# 1707/1707 [==============================] - 18s 11ms/step - loss: 0.0036 - accuracy: 0.9988 - val_loss: 0.3839 - val_accuracy: 0.9088
#
# Epoch 00017: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# Epoch 18/100
# 1707/1707 [==============================] - 19s 11ms/step - loss: 0.0021 - accuracy: 0.9995 - val_loss: 0.6169 - val_accuracy: 0.8632
# Epoch 19/100
# 1707/1707 [==============================] - 19s 11ms/step - loss: 0.0018 - accuracy: 0.9996 - val_loss: 0.2087 - val_accuracy: 0.9511
# Epoch 20/100
# 1707/1707 [==============================] - 19s 11ms/step - loss: 0.0022 - accuracy: 0.9992 - val_loss: 0.2984 - val_accuracy: 0.9341
# Epoch 21/100
# 1707/1707 [==============================] - 19s 11ms/step - loss: 0.0016 - accuracy: 0.9996 - val_loss: 0.4135 - val_accuracy: 0.9055
# Epoch 22/100
# 1707/1707 [==============================] - 19s 11ms/step - loss: 0.0013 - accuracy: 0.9997 - val_loss: 0.2590 - val_accuracy: 0.9434
#
# Epoch 00022: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# Epoch 23/100
# 1707/1707 [==============================] - 19s 11ms/step - loss: 0.0014 - accuracy: 0.9997 - val_loss: 0.4366 - val_accuracy: 0.9038
# Epoch 24/100
# 1707/1707 [==============================] - 20s 12ms/step - loss: 0.0014 - accuracy: 0.9996 - val_loss: 0.3576 - val_accuracy: 0.9187
# Epoch 25/100
# 1707/1707 [==============================] - 19s 11ms/step - loss: 0.0014 - accuracy: 0.9996 - val_loss: 0.3562 - val_accuracy: 0.9187
#
# Epoch 00025: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# Epoch 26/100
# 1707/1707 [==============================] - 19s 11ms/step - loss: 0.0011 - accuracy: 0.9998 - val_loss: 0.3279 - val_accuracy: 0.9225
# Epoch 27/100
# 1707/1707 [==============================] - 19s 11ms/step - loss: 0.0013 - accuracy: 0.9996 - val_loss: 0.3521 - val_accuracy: 0.9159
# Epoch 28/100
# 1707/1707 [==============================] - 19s 11ms/step - loss: 0.0013 - accuracy: 0.9996 - val_loss: 0.3768 - val_accuracy: 0.9121
#
# Epoch 00028: ReduceLROnPlateau reducing learning rate to 1e-05.
# Epoch 29/100
# 1707/1707 [==============================] - 19s 11ms/step - loss:
100
# 1707/1707 [==============================] - 19s 11ms/step - loss: 0.0010 - accuracy: 0.9997 - val_loss: 0.0214 - val_accuracy: 0.9945
# 1707/1707 [==============================] - 9s 5ms/step - loss: 1.0181e-05 - accuracy: 1.0000
# Train:  [1.0180883691646159e-05, 1.0]
# 57/57 [==============================] - 0s 5ms/step - loss: 0.0214 - accuracy: 0.9945
# Valid:  [0.021390892565250397, 0.9945054650306702]

# %%
plt.figure(figsize=(14, 10))
for i,k in enumerate(["Crop", "Flip", "Flip and Bright"]):
    plt.ylim(0.0, 1)
    plt.plot(history_list_2[i].history["val_accuracy"], label=str(k))
plt.legend(loc="lower right")

# %%
history_list_2[1].history["val_accuracy"]
# Out:
# [0.7835164666175842,
#  0.8538461327552795,
#  0.5642856955528259,
#  0.9362637400627136,
#  0.7318681478500366,
#  0.9456043839454651,
#  0.9549450278282166,
#  0.9862637519836426,
#  0.8659340739250183,
#  0.9917582273483276,
#  0.9027472734451294,
#  0.9604395627975464,
#  0.8208791017532349,
#  0.9950549602508545,
#  0.9516483545303345,
#  0.9895604252815247,
#  0.9928571581840515,
#  0.9945054650306702,
#  0.9961538314819336,
#  0.9961538314819336,
#  0.8961538672447205,
#  0.997802197933197,
#  0.9780219793319702,
#  0.9950549602508545,
#  0.9961538314819336,
#  0.8538461327552795,
#  0.9939560294151306,
#  0.9961538314819336,
#  0.9972527623176575,
#  0.9972527623176575,
#  0.9972527623176575,
#  0.9972527623176575]

# %%
history_list_2[2].history["val_accuracy"]
# Out:
# [0.8329670429229736,
#  0.9505494236946106,
#  0.9675824046134949,
#  0.9313187003135681,
#  0.845604419708252,
#  0.8258242011070251,
#  0.9857142567634583,
#  0.9890109896659851,
#  0.9873626232147217,
#  0.9802197813987732,
#  0.9890109896659851,
#  0.9895604252815247,
#  0.9939560294151306,
#  0.9945054650306702,
#  0.9967032670974731,
#  0.9934065937995911,
#  0.9912087917327881,
#  0.9082417488098145,
#  0.9967032670974731,
#  0.9945054650306702,
#  0.9939560294151306,
#  0.9967032670974731,
#  0.9890109896659851,
#  0.9967032670974731,
#  0.9945054650306702]

# %%
history_list_3=[]

for i in [transform_crop, transform_fiip, transform_flip_bright]:
    X_train_, y_train_ = make_train_data(i)
    y_train_ = y_train_.reshape(-1, 1)
    y_train_ = encoder.transform(y_train_)
    
    dr_ratio=0.4

    Input = keras.layers.Input(shape=X_train_[0].shape)

    x = keras.layers.Conv2D(16, kernel_size=3, activation="relu",kernel_initializer="he_normal", padding="same")(Input)
    x = keras.layers.BatchNormalization()(x)
    x = keras.layers.MaxPool2D(2)(x)

    x = keras.layers.Dropout(dr_ratio)(x)

    shortcut =x
    x = keras.layers.Conv2D(32, kernel_size=3, activation="relu",kernel_initializer="he_normal", padding="same")(x)
    x = keras.layers.BatchNormalization()(x)
    x = keras.layers.Conv2D(32, kernel_size=3, activation="relu",kernel_initializer="he_normal", padding="same")(x)
    # x = keras.layers.BatchNormalization()(x)
    # x = keras.layers.Conv2D(32, kernel_size=3, activation="relu",kernel_initializer="he_normal", padding="same")(x)
    shortcut = keras.layers.Conv2D(32, kernel_size=5, activation="relu",kernel_initializer="he_normal", padding="same")(shortcut)
    x = keras.layers.Add()([x, shortcut])
    x   = keras.layers.BatchNormalization()(x)
    x = keras.layers.MaxPool2D(2)(x)


    x = keras.layers.Dropout(dr_ratio)(x)


    shortcut =x
    x = keras.layers.Conv2D(64, kernel_size=3, activation="relu",kernel_initializer="he_normal", padding="same")(x)
    x = keras.layers.BatchNormalization()(x)
    x = keras.layers.Conv2D(64, kernel_size=3, activation="relu",kernel_initializer="he_normal", padding="same")(x)
    # x = keras.layers.BatchNormalization()(x)
    # x = keras.layers.Conv2D(64, kernel_size=3, activation="relu",kernel_initializer="he_normal", padding="same")(x)
    shortcut = keras.layers.Conv2D(64, kernel_size=3, activation="relu",kernel_initializer="he_normal", padding="same")(shortcut)
    x = keras.layers.Add()([x, shortcut])
    x = keras.layers.BatchNormalization()(x)
    x = keras.layers.MaxPool2D(2)(x)

    x = keras.layers.Dropout(dr_ratio)(x)

    shortcut =x
    x = keras.layers.Conv2D(128, kernel_size=3, activation="relu",kernel_initializer="he_normal", padding="same")(x)
    x = keras.layers.BatchNormalization()(x)
    x = keras.layers.Conv2D(128, kernel_size=3, activation="relu",kernel_initializer="he_normal", padding="same")(x)
    # x = keras.layers.BatchNormalization()(x)
    # x = keras.layers.Conv2D(128, kernel_size=3, activation="relu",kernel_initializer="he_normal", padding="same")(x)
    shortcut = keras.layers.Conv2D(128, kernel_size=3, activation="relu",kernel_initializer="he_normal", padding="same")(shortcut)
    x = keras.layers.Add()([x, shortcut])
    x = keras.layers.BatchNormalization()(x)
    x = keras.layers.MaxPool2D(2)(x)

    x = keras.layers.Dropout(dr_ratio)(x)


    x = keras.layers.GlobalAveragePooling2D()(x)
    Output = keras.layers.Dense(4, activation="softmax")(x)

    model = keras.models.Model(inputs = Input, outputs = Output)
    model.compile(loss="categorical_crossentropy",
    optimizer=keras.optimizers.Adam(learning_rate=0.001), metrics=["accuracy"])

    history_list_3.append(model.fit(X_train_, y_train_, validation_data=(X_test, y_test),callbacks=[es, reduce_lr],epochs = 100))
    print("Train: ", model.evaluate(X_train_, y_train_))
    print("Valid: ", model.evaluate(X_test, y_test))
# Out:
# Epoch 1/100
# 1707/1707 [==============================] - 20s 11ms/step - loss: 0.5724 - accuracy: 0.7607 - val_loss: 0.3927 - val_accuracy: 0.8538
# Epoch 2/100
# 1707/1707 [==============================] - 19s 11ms/step - loss: 0.2945 - accuracy: 0.8872 - val_loss: 4.8875 - val_accuracy: 0.3698
# Epoch 3/100
# 1707/1707 [==============================] - 19s 11ms/step - loss: 0.2087 - accuracy: 0.9221 - val_loss: 1.4812 - val_accuracy: 0.6769
# Epoch 4/100
# 1707/1707 [==============================] - 19s 11ms/step - loss: 0.1676 - accuracy: 0.9377 - val_loss: 1.0096 - val_accuracy: 0.7571
#
# Epoch 00004: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 5/100
# 1707/1707 [==============================] - 18s 11ms/step - loss: 0.1150 - accuracy: 0.9566 - val_loss: 2.0526 - val_accuracy: 0.5852
# Epoch 6/100
# 1707/1707 [==============================] - 18s 11ms/step - loss: 0.0983 - accuracy: 0.9652 - val_loss: 0.4519 - val_accuracy: 0.8846
# Epoch 7/100
# 1707/1707 [==============================] - 18s 11ms/step - loss: 0.0934 - accuracy: 0.9646 - val_loss: 0.2061 - val_accuracy: 0.9363
# Epoch 8/100
# 1707/1707 [==============================] - 18s 11ms/step - loss: 0.0821 - accuracy: 0.9701 - val_loss: 0.2464 - val_accuracy: 0.9225
# Epoch 9/100
# 1707/1707 [==============================] - 19s 11ms/step - loss: 0.0762 - accuracy: 0.9732 - val_loss: 0.2254 - val_accuracy: 0.9286
# Epoch 10/100
# 1707/1707 [==============================] - 18s 11ms/step - loss: 0.0690 - accuracy: 0.9752 - val_loss: 0.8297 - val_accuracy: 0.8082
#
# Epoch 00010: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Epoch 11/100
# 1707/1707 [==============================] - 18s 11ms/step - loss: 0.0511 - accuracy: 0.9812 - val_loss: 1.6472 - val_accuracy: 0.7236
# Epoch 12/100
# 1707/1707 [==============================] - 19s 11ms/step - loss: 0.0486 - accuracy: 0.9828 - val_loss: 0.1827 - val_accuracy: 0.9434
# Epoch 13/100
# 1707/1707 [==============================] - 19s 11ms/step - loss: 0.0461 - accuracy: 0.9839 - val_loss: 0.2527 - val_accuracy: 0.9368
# Epoch 14/100
# 1707/1707 [==============================] - 19s 11ms/step - loss: 0.0431 - accuracy: 0.9849 - val_loss: 0.4381 - val_accuracy: 0.8890
# Epoch 15/100
# 1707/1707 [==============================] - 19s 11ms/step - loss: 0.0395 - accuracy: 0.9860 - val_loss: 0.2416 - val_accuracy: 0.9385
#
# Epoch 00015: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# Epoch 16/100
# 1707/1707 [==============================] - 19s 11ms/step - loss: 0.0334 - accuracy: 0.9882 - val_loss: 0.2412 - val_accuracy: 0.9341
# Epoch 17/100
# 1707/1707 [==============================] - 19s 11ms/step - loss: 0.0324 - accuracy: 0.9885 - val_loss: 0.2146 - val_accuracy: 0.9440
# Epoch 18/100
# 1707/1707 [==============================] - 19s 11ms/step - loss: 0.0296 - accuracy: 0.9892 - val_loss: 0.2663 - val_accuracy: 0.9324
#
# Epoch 00018: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# Epoch 19/100
# 1707/1707 [==============================] - 19s 11ms/step - loss: 0.0282 - accuracy: 0.9897 - val_loss: 0.2926 - val_accuracy: 0.9341
# Epoch 20/100
# 1707/1707 [==============================] - 19s 11ms/step - loss: 0.0258 - accuracy: 0.9912 - val_loss: 0.2275 - val_accuracy: 0.9445
# Epoch 21/100
# 1707/1707 [==============================] - 19s 11ms/step - loss: 0.0251 - accuracy: 0.9914 - val_loss: 0.2501 - val_accuracy: 0.9401
#
# Epoch 00021: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# Epoch 22/100
# 1707/1707 [==============================] - 18s 11ms/step - loss: 0.0243 - accuracy: 0.9913 - val_loss: 0.2066 - val_accuracy: 0.9445
# Epoch 23/100
# 1707/1707 [==============================] - 18s 11ms/step - loss: 0.
100
# 1707/1707 [==============================] - 19s 11ms/step - loss: 0.0217 - accuracy: 0.9926 - val_loss: 0.9529 - val_accuracy: 0.8011
# 1707/1707 [==============================] - 8s 5ms/step - loss: 0.8493 - accuracy: 0.8290
# Train:  [0.8493371605873108, 0.8289743661880493]
# 57/57 [==============================] - 0s 5ms/step - loss: 0.9529 - accuracy: 0.8011
# Valid:  [0.9528970122337341, 0.8010988831520081]

# %%
plt.figure(figsize=(14, 10))
for i,k in enumerate(["Crop", "Flip", "Flip and Bright"]):
    plt.ylim(0.0, 1)
    plt.plot(history_list_3[i].history["val_accuracy"], label=str(k))
plt.legend(loc="lower right")

# %%
history_list_3[1].history["val_accuracy"]
# Out:
# [0.7648351788520813,
#  0.8560439348220825,
#  0.807692289352417,
#  0.5659340620040894,
#  0.9038461446762085,
#  0.8494505286216736,
#  0.9505494236946106,
#  0.8521978259086609,
#  0.8450549244880676,
#  0.8725274801254272,
#  0.9824175834655762,
#  0.9769230484962463,
#  0.9148351550102234,
#  0.9538461565971375,
#  0.9917582273483276,
#  0.9813186526298523,
#  0.7884615659713745,
#  0.9791208505630493,
#  0.9945054650306702,
#  0.9824175834655762,
#  0.9796703457832336,
#  0.9967032670974731,
#  0.9862637519836426,
#  0.9912087917327881,
#  0.9972527623176575,
#  0.997802197933197,
#  0.9961538314819336,
#  0.9934065937995911,
#  0.9961538314819336,
#  0.9972527623176575,
#  0.9967032670974731,
#  0.9961538314819336,
#  0.997802197933197,
#  0.9972527623176575,
#  0.995604395866394,
#  0.9961538314819336]

# %%
history_list_3[2].history["val_accuracy"]
# Out:
# [0.5131868124008179,
#  0.7510989308357239,
#  0.8664835095405579,
#  0.8351648449897766,
#  0.8384615182876587,
#  0.6313186883926392,
#  0.8346154093742371,
#  0.8873626589775085,
#  0.8681318759918213,
#  0.8417582511901855,
#  0.8956043720245361,
#  0.8582417368888855,
#  0.8675824403762817,
#  0.7483516335487366,
#  0.8587912321090698,
#  0.791208803653717,
#  0.7774725556373596,
#  0.8472527265548706,
#  0.8642857074737549,
#  0.8197802305221558,
#  0.8010988831520081]

# %%
history_list_4=[]

for i in [transform_crop, transform_fiip, transform_flip_bright]:
    X_train_, y_train_ = make_train_data(i)
    y_train_ = y_train_.reshape(-1, 1)
    y_train_ = encoder.transform(y_train_)
    

    Input = keras.layers.Input(shape=X_train_[0].shape)

    x = keras.layers.Conv2D(16, kernel_size=3, activation="relu",kernel_initializer="he_normal", padding="same")(Input)
    x = keras.layers.BatchNormalization()(x)
    x = keras.layers.MaxPool2D(2)(x)


    shortcut =x
    x = keras.layers.Conv2D(32, kernel_size=3, activation="relu",kernel_initializer="he_normal", padding="same")(x)
    x = keras.layers.BatchNormalization()(x)
    x = keras.layers.Conv2D(32, kernel_size=3, activation="relu",kernel_initializer="he_normal", padding="same")(x)
    # x = keras.layers.BatchNormalization()(x)
    # x = keras.layers.Conv2D(32, kernel_size=3, activation="relu",kernel_initializer="he_normal", padding="same")(x)
    shortcut = keras.layers.Conv2D(32, kernel_size=5, activation="relu",kernel_initializer="he_normal", padding="same")(shortcut)
    x = keras.layers.Add()([x, shortcut])
    x   = keras.layers.BatchNormalization()(x)
    x = keras.layers.MaxPool2D(2)(x)




    shortcut =x
    x = keras.layers.Conv2D(64, kernel_size=3, activation="relu",kernel_initializer="he_normal", padding="same")(x)
    x = keras.layers.BatchNormalization()(x)
    x = keras.layers.Conv2D(64, kernel_size=3, activation="relu",kernel_initializer="he_normal", padding="same")(x)
    # x = keras.layers.BatchNormalization()(x)
    # x = keras.layers.Conv2D(64, kernel_size=3, activation="relu",kernel_initializer="he_normal", padding="same")(x)
    shortcut = keras.layers.Conv2D(64, kernel_size=3, activation="relu",kernel_initializer="he_normal", padding="same")(shortcut)
    x = keras.layers.Add()([x, shortcut])
    x = keras.layers.BatchNormalization()(x)
    x = keras.layers.MaxPool2D(2)(x)


    shortcut =x
    x = keras.layers.Conv2D(128, kernel_size=3, activation="relu",kernel_initializer="he_normal", padding="same")(x)
    x = keras.layers.BatchNormalization()(x)
    x = keras.layers.Conv2D(128, kernel_size=3, activation="relu",kernel_initializer="he_normal", padding="same")(x)
    # x = keras.layers.BatchNormalization()(x)
    # x = keras.layers.Conv2D(128, kernel_size=3, activation="relu",kernel_initializer="he_normal", padding="same")(x)
    shortcut = keras.layers.Conv2D(128, kernel_size=3, activation="relu",kernel_initializer="he_normal", padding="same")(shortcut)
    x = keras.layers.Add()([x, shortcut])
    x = keras.layers.BatchNormalization()(x)
    x = keras.layers.MaxPool2D(2)(x)



    x = keras.layers.GlobalAveragePooling2D()(x)
    Output = keras.layers.Dense(4, activation="softmax")(x)

    model = keras.models.Model(inputs = Input, outputs = Output)
    model.compile(loss="categorical_crossentropy",
    optimizer=keras.optimizers.Adam(learning_rate=0.001), metrics=["accuracy"])

    history_list_4.append(model.fit(X_train_, y_train_, validation_data=(X_test, y_test),callbacks=[es, reduce_lr],epochs = 100))
    print("Train: ", model.evaluate(X_train_, y_train_))
    print("Valid: ", model.evaluate(X_test, y_test))
# Out:
# Epoch 1/100
# 1707/1707 [==============================] - 19s 10ms/step - loss: 0.3505 - accuracy: 0.8600 - val_loss: 0.6590 - val_accuracy: 0.7863
# Epoch 2/100
# 1707/1707 [==============================] - 17s 10ms/step - loss: 0.1381 - accuracy: 0.9505 - val_loss: 0.3956 - val_accuracy: 0.8797
# Epoch 3/100
# 1707/1707 [==============================] - 18s 10ms/step - loss: 0.0834 - accuracy: 0.9701 - val_loss: 0.7916 - val_accuracy: 0.7769
# Epoch 4/100
# 1707/1707 [==============================] - 18s 10ms/step - loss: 0.0606 - accuracy: 0.9784 - val_loss: 0.6228 - val_accuracy: 0.8280
# Epoch 5/100
# 1707/1707 [==============================] - 18s 10ms/step - loss: 0.0473 - accuracy: 0.9828 - val_loss: 0.2751 - val_accuracy: 0.9093
# Epoch 6/100
# 1707/1707 [==============================] - 18s 11ms/step - loss: 0.0354 - accuracy: 0.9874 - val_loss: 1.3578 - val_accuracy: 0.7236
# Epoch 7/100
# 1707/1707 [==============================] - 19s 11ms/step - loss: 0.0320 - accuracy: 0.9882 - val_loss: 1.5932 - val_accuracy: 0.7236
# Epoch 8/100
# 1707/1707 [==============================] - 19s 11ms/step - loss: 0.0230 - accuracy: 0.9921 - val_loss: 1.5292 - val_accuracy: 0.7049
#
# Epoch 00008: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 9/100
# 1707/1707 [==============================] - 19s 11ms/step - loss: 0.0076 - accuracy: 0.9974 - val_loss: 0.9648 - val_accuracy: 0.7945
# Epoch 10/100
# 1707/1707 [==============================] - 19s 11ms/step - loss: 0.0084 - accuracy: 0.9974 - val_loss: 1.8645 - val_accuracy: 0.7000
# Epoch 11/100
# 1707/1707 [==============================] - 19s 11ms/step - loss: 0.0073 - accuracy: 0.9975 - val_loss: 1.0198 - val_accuracy: 0.8066
#
# Epoch 00011: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Epoch 12/100
# 1707/1707 [==============================] - 19s 11ms/step - loss: 0.0023 - accuracy: 0.9995 - val_loss: 0.7849 - val_accuracy: 0.8308
# Epoch 13/100
# 1707/1707 [==============================] - 19s 11ms/step - loss: 0.0012 - accuracy: 0.9997 - val_loss: 0.6221 - val_accuracy: 0.8703
# Epoch 14/100
# 1707/1707 [==============================] - 19s 11ms/step - loss: 0.0025 - accuracy: 0.9992 - val_loss: 1.0124 - val_accuracy: 0.8181
#
# Epoch 00014: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# Epoch 15/100
# 1707/1707 [==============================] - 19s 11ms/step - loss: 8.4991e-04 - accuracy: 0.9998 - val_loss: 0.4469 - val_accuracy: 0.8989
# 1707/1707 [==============================] - 9s 5ms/step - loss: 6.2854e-05 - accuracy: 1.0000
# Train:  [6.285364361247048e-05, 1.0]
# 57/57 [==============================] - 0s 5ms/step - loss: 0.4469 - accuracy: 0.8989
# Valid:  [0.44688019156455994, 0.898901104927063]
# Epoch 1/100
# 1707/1707 [==============================] - 20s 11ms/step - loss: 0.2388 - accuracy: 0.9088 - val_loss: 1.1566 - val_accuracy: 0.7231
# Epoch 2/100
# 1707/1707 [==============================] - 18s 11ms/step - loss: 0.0720 - accuracy: 0.9742 - val_loss: 0.5060 - val_accuracy: 0.8495
# Epoch 3/100
# 1707/1707 [==============================] - 18s 10ms/step - loss: 0.0437 - accuracy: 0.9840 - val_loss: 0.2572 - val_accuracy: 0.9286
# Epoch 4/100
# 1707/1707 [==============================] - 19s 11ms/step - loss: 0.0306 - accuracy: 0.9897 - val_loss: 0.0708 - val_accuracy: 0.9780
# Epoch 5/100
# 1707/1707 [==============================] - 19s 11ms/step - loss: 0.0259 - accuracy: 0.9905 - val_loss: 0.0682 - val_accuracy: 0.9780
# Epoch 6/100
# 1707/1707 [==============================] - 18s 11ms/step - loss: 0.
100
# 1707/1707 [==============================] - 18s 11ms/step - loss: 0.0135 - accuracy: 0.9957 - val_loss: 0.1081 - val_accuracy: 0.9632
# Epoch 6/100
# 1707/1707 [==============================] - 19s 11ms/step - loss: 0.0139 - accuracy: 0.9951 - val_loss: 0.0409 - val_accuracy: 0.9896
# Epoch 7/100
# 1707/1707 [==============================] - 18s 11ms/step - loss: 0.0095 - accuracy: 0.9969 - val_loss: 0.0755 - val_accuracy: 0.9764
# Epoch 8/100
# 1707/1707 [==============================] - 19s 11ms/step - loss: 0.0121 - accuracy: 0.9958 - val_loss: 0.0476 - val_accuracy: 0.9808
# Epoch 9/100
# 1707/1707 [==============================] - 18s 11ms/step - loss: 0.0083 - accuracy: 0.9972 - val_loss: 0.1016 - val_accuracy: 0.9725
#
# Epoch 00009: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Epoch 10/100
# 1707/1707 [==============================] - 19s 11ms/step - loss: 0.0028 - accuracy: 0.9992 - val_loss: 0.1333 - val_accuracy: 0.9593
# Epoch 11/100
# 1707/1707 [==============================] - 19s 11ms/step - loss: 0.0019 - accuracy: 0.9995 - val_loss: 0.2620 - val_accuracy: 0.9291
# Epoch 12/100
# 1707/1707 [==============================] - 19s 11ms/step - loss: 0.0028 - accuracy: 0.9991 - val_loss: 0.0807 - val_accuracy: 0.9835
#
# Epoch 00012: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# Epoch 13/100
# 1707/1707 [==============================] - 19s 11ms/step - loss: 0.0014 - accuracy: 0.9996 - val_loss: 0.0306 - val_accuracy: 0.9901
# Epoch 14/100
# 1707/1707 [==============================] - 18s 11ms/step - loss: 0.0011 - accuracy: 0.9998 - val_loss: 0.0203 - val_accuracy: 0.9940
# Epoch 15/100
# 1707/1707 [==============================] - 18s 11ms/step - loss: 2.8828e-04 - accuracy: 1.0000 - val_loss: 0.0306 - val_accuracy: 0.9918
# Epoch 16/100
# 1707/1707 [==============================] - 18s 11ms/step - loss: 7.0995e-04 - accuracy: 0.9999 - val_loss: 0.0313 - val_accuracy: 0.9923
# Epoch 17/100
# 1707/1707 [==============================] - 18s 11ms/step - loss: 5.7329e-04 - accuracy: 0.9999 - val_loss: 0.0251 - val_accuracy: 0.9940
#
# Epoch 00017: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# Epoch 18/100
# 1707/1707 [==============================] - 18s 11ms/step - loss: 2.5002e-04 - accuracy: 1.0000 - val_loss: 0.0258 - val_accuracy: 0.9929
# Epoch 19/100
# 1707/1707 [==============================] - 18s 11ms/step - loss: 1.7840e-04 - accuracy: 1.0000 - val_loss: 0.0293 - val_accuracy: 0.9929
# Epoch 20/100
# 1707/1707 [==============================] - 18s 11ms/step - loss: 1.1318e-04 - accuracy: 1.0000 - val_loss: 0.0290 - val_accuracy: 0.9945
#
# Epoch 00020: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# Epoch 21/100
# 1707/1707 [==============================] - 18s 11ms/step - loss: 1.5106e-04 - accuracy: 1.0000 - val_loss: 0.0253 - val_accuracy: 0.9940
# Epoch 22/100
# 1707/1707 [==============================] - 18s 11ms/step - loss: 1.8395e-04 - accuracy: 1.0000 - val_loss: 0.0236 - val_accuracy: 0.9945
# Epoch 23/100
# 1707/1707 [==============================] - 18s 11ms/step - loss: 5.3232e-05 - accuracy: 1.0000 - val_loss: 0.0248 - val_accuracy: 0.9940
#
# Epoch 00023: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# Epoch 24/100
# 1707/1707 [==============================] - 19s 11ms/step - loss: 4.8701e-05 - accuracy: 1.0000 - val_loss: 0.0264 - val_accuracy: 0.9940
# Epoch 25/100
# 1707/1707 [==============================] - 19s 11ms/step - loss: 4.0166e-05 - accuracy: 1.0000 - val_loss: 0.0202 - val_accuracy: 0.9956
# Epoch 26/100
# 1707/1707 [==============================] - 19s 11ms/step - loss: 6.8138e-05 - accuracy: 1.0000 - val_loss: 0.0212 - val_accuracy: 0.9951
#
# Epoch 00026: ReduceLROnPlateau reducing learning rate to 1e-05.
# Epoch 27/100
# 1707/1707 [==============================] - 18s 11ms/step - loss: 3.7497e-05 - accuracy: 1.0000 - val_loss: 0.0223 - val_accuracy: 0.9951
# Epoch 28/100
# 1707/1707 [==============================] - 18s 11ms/step - loss: 6.0373e-05 - accuracy: 1.0000 - val_loss: 0.0234 - val_accuracy: 0.9951
# Epoch 29/100
# 1707/1707 [==============================] - 18s 11ms/step - loss: 4.5236e-05 - accuracy: 1.0000 - val_loss: 0.0223 - val_accuracy: 0.9951
# Epoch 30/100
# 1707/1707 [==============================] - 18s 11ms/step - loss: 3.4101e-05 - accuracy: 1.0000 - val_loss: 0.0224 - val_accuracy: 0.9951
# Epoch 31/100
# 1707/1707 [==============================] - 19s 11ms/step - loss: 3.6305e-05 - accuracy: 1.0000 - val_loss: 0.0246 - val_accuracy: 0.9951
# Epoch 32/100
# 1707/1707 [==============================] - 19s 11ms/step - loss: 3.1466e-05 - accuracy: 1.0000 - val_loss: 0.0217 - val_accuracy: 0.9951.1480e
# Epoch 33/100
# 1707/1707 [==============================] - 18s 11ms/step - loss: 6.7927e-05 - accuracy: 1.0000 - val_loss: 0.0222 - val_accuracy: 0.9945
# Epoch 34/100
# 1707/1707 [==============================] - 19s 11ms/step - loss: 2.1987e-05 - accuracy: 1.0000 - val_loss: 0.0215 - val_accuracy: 0.9945
# Epoch 35/100
# 1707/1707 [==============================] - 19s 11ms/step - loss: 3.8228e-05 - accuracy: 1.0000 - val_loss: 0.0231 - val_accuracy: 0.9945
# ---------------------------------------------------------------------------
# InternalError                             Traceback (most recent call last)
# Input In [34], in <cell line: 3>()
#      59 model.compile(loss="categorical_crossentropy",
#      60 optimizer=keras.optimizers.Adam(learning_rate=0.001), metrics=["accuracy"])
#      62 history_list_4.append(model.fit(X_train_, y_train_, validation_data=(X_test, y_test),callbacks=[es, reduce_lr],epochs = 100))
# ---> 63 print("Train: ", model.evaluate(X_train_, y_train_))
#      64 print("Valid: ", model.evaluate(X_test, y_test))
#
# File ~\anaconda3\envs\python3.9.0\lib\site-packages\tensorflow\python\keras\engine\training.py:1464, in Model.evaluate(self, x, y, batch_size, verbose, sample_weight, steps, callbacks, max_queue_size, workers, use_multiprocessing, return_dict, **kwargs)
#    1461   data_handler = self._eval_data_handler
#    1462 else:
#    1463   # Creates a `tf.data.Dataset` and handles batch and epoch iteration.
# -> 1464   data_handler = data_adapter.get_data_handler(
#    1465       x=x,
#    1466       y=y,
#    1467       sample_weight=sample_weight,
#    1468       batch_size=batch_size,
#    1469       steps_per_epoch=steps,
#    1470       initial_epoch=0,
#    1471       epochs=1,
#    1472       max_queue_size=max_queue_size,
#    1473       workers=workers,
#    1474       use_multiprocessing=use_multiprocessing,
#    1475       model=self,
#    1476       steps_per_execution=self._steps_per_execution)
#    1478 # Container that configures and calls `tf.keras.Callback`s.
#    1479 if not isinstance(callbacks, callbacks_module.CallbackList):
#
# File ~\anaconda3\envs\python3.9.0\lib\site-packages\tensorflow\python\keras\engine\data_adapter.py:1394, in get_data_handler(*args, **kwargs)
#    1392 if getattr(kwargs["model"], "_cluster_coordinator", None):
#    1393   return _ClusterCoordinatorDataHandler(*args, **kwargs)
# -> 1394 return DataHandler(*args, **kwargs)
#
# File ~\anaconda3\envs\python3.9.0\lib\site-packages\tensorflow\python\keras\engine\data_adapter.py:1149, in DataHandler.__init__(self, x, y, sample_weight, batch_size, steps_per_epoch, initial_epoch, epochs, shuffle, class_weight, max_queue_size, workers, use_multiprocessing, model, steps_per_execution, distribute)
#    1146   self._steps_per_execution_value = steps_per_execution.numpy().item()
#    1148 adapter_cls = select_data_adapter(x, y)
# -> 1149 self._adapter = adapter_cls(
#    1150     x,
#    1151     y,
#    1152     batch_size=batch_size,
#    1153     steps=steps_per_epoch,
#    1154     epochs=epochs - initial_epoch,
#    1155     sample_weights=sample_weight,
#    1156     shuffle=shuffle,
#    1157     max_queue_size=max_queue_size,
#    1158     workers=workers,
#    1159     use_multiprocessing=use_multiprocessing,
#    1160     distribution_strategy=ds_context.get_strategy(),
#    1161     model=model)
#    1163 strategy = ds_context.get_strategy()
#    1165 self._current_step = 0
#
# File ~\anaconda3\envs\python3.9.0\lib\site-packages\tensorflow\python\keras\engine\data_adapter.py:243, in TensorLikeDataAdapter.__init__(self, x, y, sample_weights, sample_weight_modes, batch_size, epochs, steps, shuffle, **kwargs)
#     232 def __init__(self,
#     233              x,
#     234              y=None,
#    (...)
#     240              shuffle=False,
#     241              **kwargs):
#     242   super(TensorLikeDataAdapter, self).__init__(x, y, **kwargs)
# --> 243   x, y, sample_weights = _process_tensorlike((x, y, sample_weights))
#     244   sample_weight_modes = broadcast_sample_weight_modes(
#     245       sample_weights, sample_weight_modes)
#     247   # If sample_weights are not specified for an output use 1.0 as weights.
#
# File ~\anaconda3\envs\python3.9.0\lib\site-packages\tensorflow\python\keras\engine\data_adapter.py:1042, in _process_tensorlike(inputs)
#    1039     return _scipy_sparse_to_sparse_tensor(x)
#    1040   return x
# -> 1042 inputs = nest.map_structure(_convert_numpy_and_scipy, inputs)
#    1043 return nest.list_to_tuple(inputs)
#
# File ~\anaconda3\envs\python3.9.0\lib\site-packages\tensorflow\python\util\nest.py:869, in map_structure(func, *structure, **kwargs)
#     865 flat_structure = (flatten(s, expand_composites) for s in structure)
#     866 entries = zip(*flat_structure)
#     868 return pack_sequence_as(
# --> 869     structure[0], [func(*x) for x in entries],
#     870     expand_composites=expand_composites)
#
# File ~\anaconda3\envs\python3.9.0\lib\site-packages\tensorflow\python\util\nest.py:869, in <listcomp>(.0)
#     865 flat_structure = (flatten(s, expand_composites) for s in structure)
#     866 entries = zip(*flat_structure)
#     868 return pack_sequence_as(
# --> 869     structure[0], [func(*x) for x in entries],
#     870     expand_composites=expand_composites)
#
# File ~\anaconda3\envs\python3.9.0\lib\site-packages\tensorflow\python\keras\engine\data_adapter.py:1037, in _process_tensorlike.<locals>._convert_numpy_and_scipy(x)
#    1035   if issubclass(x.dtype.type, np.floating):
#    1036     dtype = backend.floatx()
# -> 1037   return ops.convert_to_tensor_v2_with_dispatch(x, dtype=dtype)
#    1038 elif _is_scipy_sparse(x):
#    1039   return _scipy_sparse_to_sparse_tensor(x)
#
# File ~\anaconda3\envs\python3.9.0\lib\site-packages\tensorflow\python\util\traceback_utils.py:153, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
# --> 153   raise e.with_traceback(filtered_tb) from None
#     154 finally:
#     155   del filtered_tb
#
# File ~\anaconda3\envs\python3.9.0\lib\site-packages\tensorflow\python\framework\constant_op.py:106, in convert_to_eager_tensor(value, ctx, dtype)
#     104     dtype = dtypes.as_dtype(dtype).as_datatype_enum
#     105 ctx.ensure_initialized()
# --> 106 return ops.EagerTensor(value, ctx.device_name, dtype)
#
# InternalError: Failed copying input tensor from /job:localhost/replica:0/task:0/device:CPU:0 to /job:localhost/replica:0/task:0/device:GPU:0 in order to run _EagerConst: Dst tensor is not initialized.

# %%
plt.figure(figsize=(14, 10))
for i,k in enumerate(["Crop", "Flip", "Flip and Bright"]):
    plt.ylim(0.0, 1)
    plt.plot(history_list_4[i].history["val_accuracy"], label=str(k))
plt.legend(loc="lower right")

# %%
history_list_4[1].history["val_accuracy"]
# Out:
# [0.7230769395828247,
#  0.8494505286216736,
#  0.9285714030265808,
#  0.9780219793319702,
#  0.9780219793319702,
#  0.5813186764717102,
#  0.9335165023803711,
#  0.9434065818786621,
#  0.841208815574646,
#  0.9939560294151306,
#  0.9890109896659851,
#  0.7406593561172485,
#  0.9818681478500366,
#  0.9961538314819336,
#  0.995604395866394,
#  0.9714285731315613,
#  0.9917582273483276,
#  0.9950549602508545,
#  0.9972527623176575,
#  0.997802197933197,
#  0.9961538314819336,
#  0.9895604252815247,
#  0.9967032670974731,
#  0.9967032670974731,
#  0.9961538314819336,
#  0.9961538314819336,
#  0.9961538314819336,
#  0.9967032670974731,
#  0.9972527623176575,
#  0.9972527623176575]

# %%
history_list_4[2].history["val_accuracy"]
# Out:
# [0.9186813235282898,
#  0.9071428775787354,
#  0.7708791494369507,
#  0.5741758346557617,
#  0.9631868004798889,
#  0.9895604252815247,
#  0.9763736128807068,
#  0.9807692170143127,
#  0.9725274443626404,
#  0.9593406319618225,
#  0.9291208982467651,
#  0.9835164546966553,
#  0.9901098608970642,
#  0.9939560294151306,
#  0.9917582273483276,
#  0.9923076629638672,
#  0.9939560294151306,
#  0.9928571581840515,
#  0.9928571581840515,
#  0.9945054650306702,
#  0.9939560294151306,
#  0.9945054650306702,
#  0.9939560294151306,
#  0.9939560294151306,
#  0.995604395866394,
#  0.9950549602508545,
#  0.9950549602508545,
#  0.9950549602508545,
#  0.9950549602508545,
#  0.9950549602508545,
#  0.9950549602508545,
#  0.9950549602508545,
#  0.9945054650306702,
#  0.9945054650306702,
#  0.9945054650306702]

# %%
hist_list = joblib.load("history_list.pkl")

# %%
plt.figure(figsize=(14, 10))
plt.plot(hist_list[1]["val_accuracy"], label="Dropout=.02")
plt.plot(history_list_4[1].history["val_accuracy"], label="No Drop out")
plt.ylim(0.9, 1)
plt.legend()

# %% [markdown]
# # Validation by K-fold

# %%
def make_model(X_train_, y_train_,X_test, y_test, dr_ratio=0.2):
    dr_ratio=0.4

    Input = keras.layers.Input(shape=X_train_[0].shape)

    x = keras.layers.Conv2D(16, kernel_size=3, activation="relu",kernel_initializer="he_normal", padding="same")(Input)
    x = keras.layers.BatchNormalization()(x)
    x = keras.layers.MaxPool2D(2)(x)

    x = keras.layers.Dropout(dr_ratio)(x)

    shortcut =x
    x = keras.layers.Conv2D(32, kernel_size=3, activation="relu",kernel_initializer="he_normal", padding="same")(x)
    x = keras.layers.BatchNormalization()(x)
    x = keras.layers.Conv2D(32, kernel_size=3, activation="relu",kernel_initializer="he_normal", padding="same")(x)
    # x = keras.layers.BatchNormalization()(x)
    # x = keras.layers.Conv2D(32, kernel_size=3, activation="relu",kernel_initializer="he_normal", padding="same")(x)
    shortcut = keras.layers.Conv2D(32, kernel_size=5, activation="relu",kernel_initializer="he_normal", padding="same")(shortcut)
    x = keras.layers.Add()([x, shortcut])
    x   = keras.layers.BatchNormalization()(x)
    x = keras.layers.MaxPool2D(2)(x)


    x = keras.layers.Dropout(dr_ratio)(x)


    shortcut =x
    x = keras.layers.Conv2D(64, kernel_size=3, activation="relu",kernel_initializer="he_normal", padding="same")(x)
    x = keras.layers.BatchNormalization()(x)
    x = keras.layers.Conv2D(64, kernel_size=3, activation="relu",kernel_initializer="he_normal", padding="same")(x)
    # x = keras.layers.BatchNormalization()(x)
    # x = keras.layers.Conv2D(64, kernel_size=3, activation="relu",kernel_initializer="he_normal", padding="same")(x)
    shortcut = keras.layers.Conv2D(64, kernel_size=3, activation="relu",kernel_initializer="he_normal", padding="same")(shortcut)
    x = keras.layers.Add()([x, shortcut])
    x = keras.layers.BatchNormalization()(x)
    x = keras.layers.MaxPool2D(2)(x)

    x = keras.layers.Dropout(dr_ratio)(x)

    shortcut =x
    x = keras.layers.Conv2D(128, kernel_size=3, activation="relu",kernel_initializer="he_normal", padding="same")(x)
    x = keras.layers.BatchNormalization()(x)
    x = keras.layers.Conv2D(128, kernel_size=3, activation="relu",kernel_initializer="he_normal", padding="same")(x)
    # x = keras.layers.BatchNormalization()(x)
    # x = keras.layers.Conv2D(128, kernel_size=3, activation="relu",kernel_initializer="he_normal", padding="same")(x)
    shortcut = keras.layers.Conv2D(128, kernel_size=3, activation="relu",kernel_initializer="he_normal", padding="same")(shortcut)
    x = keras.layers.Add()([x, shortcut])
    x = keras.layers.BatchNormalization()(x)
    x = keras.layers.MaxPool2D(2)(x)

    x = keras.layers.Dropout(dr_ratio)(x)


    x = keras.layers.GlobalAveragePooling2D()(x)
    Output = keras.layers.Dense(4, activation="softmax")(x)

    model = keras.models.Model(inputs = Input, outputs = Output)
    model.compile(loss="categorical_crossentropy",
    optimizer=keras.optimizers.Adam(learning_rate=0.001), metrics=["accuracy"])

    history = model.fit(X_train_, y_train_, validation_data=(X_test, y_test),callbacks=[es, reduce_lr],epochs = 100, verbose=0)
    print("Train: ", model.evaluate(X_train_, y_train_))
    print("Valid: ", model.evaluate(X_test, y_test))

# %%
X_train, y_train = make_train_data(transform_fiip)

# %%
fold = StratifiedKFold(n_splits=5, shuffle=True)
fold.get_n_splits(X_train, y_train)
# Out:
# 5

# %%
for train_index, test_index in fold.split(X_train, y_train):
#     print("TRAIN:", train_index, "TEST:", test_index)
    X_train_, X_test_ = X_train[train_index], X_train[test_index]
    y_train_, y_test_ = y_train[train_index], y_train[test_index]
#     print("Train label:n {}. Test label:\n {}".format(pd.Series(y_train).value_counts(), pd.Series(y_train).value_counts()))
    y_train_ = encoder.transform(y_train_.reshape(-1, 1))
    y_test_ = encoder.transform(y_test_.reshape(-1, 1))

    make_model(X_train_, y_train_, X_test_, y_test_)
# Out:
# Epoch 00010: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00018: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 00025: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 00030: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
#
# Epoch 00036: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 1365/1365 [==============================] - 6s 5ms/step - loss: 2.7597e-04 - accuracy: 1.0000
# Train:  [0.00027596583822742105, 0.9999542236328125]
# 342/342 [==============================] - 2s 5ms/step - loss: 9.3021e-04 - accuracy: 0.9995: 0s - l
# Valid:  [0.0009302059188485146, 0.9995421171188354]
#
# Epoch 00008: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00011: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 00017: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 00021: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
#
# Epoch 00024: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
#
# Epoch 00027: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 1365/1365 [==============================] - 6s 5ms/step - loss: 0.0145 - accuracy: 0.9947
# Train:  [0.014519304037094116, 0.9946886301040649]
# 342/342 [==============================] - 2s 5ms/step - loss: 0.0260 - accuracy: 0.9915
# Valid:  [0.02596028707921505, 0.9914835095405579]
# ---------------------------------------------------------------------------
# InternalError                             Traceback (most recent call last)
# Input In [76], in <cell line: 1>()
#       6 y_train_ = encoder.transform(y_train_.reshape(-1, 1))
#       7 y_test_ = encoder.transform(y_test_.reshape(-1, 1))
# ----> 9 make_model(X_train_, y_train_, X_test_, y_test_)
#
# Input In [58], in make_model(X_train_, y_train_, X_test, y_test, dr_ratio)
#      57 model = keras.models.Model(inputs = Input, outputs = Output)
#      58 model.compile(loss="categorical_crossentropy",
#      59 optimizer=keras.optimizers.Adam(learning_rate=0.001), metrics=["accuracy"])
# ---> 61 history = model.fit(X_train_, y_train_, validation_data=(X_test, y_test),callbacks=[es, reduce_lr],epochs = 100, verbose=0)
#      62 print("Train: ", model.evaluate(X_train_, y_train_))
#      63 print("Valid: ", model.evaluate(X_test, y_test))
#
# File ~\anaconda3\envs\python3.9.0\lib\site-packages\tensorflow\python\keras\engine\training.py:1139, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1133   self._cluster_coordinator = cluster_coordinator.ClusterCoordinator(
#    1134       self.distribute_strategy)
#    1136 with self.distribute_strategy.scope(), \
#    1137      training_utils.RespectCompiledTrainableState(self):
#    1138   # Creates a `tf.data.Dataset` and handles batch and epoch iteration.
# -> 1139   data_handler = data_adapter.get_data_handler(
#    1140       x=x,
#    1141       y=y,
#    1142       sample_weight=sample_weight,
#    1143       batch_size=batch_size,
#    1144       steps_per_epoch=steps_per_epoch,
#    1145       initial_epoch=initial_epoch,
#    1146       epochs=epochs,
#    1147       shuffle=shuffle,
#    1148       class_weight=class_weight,
#    1149       max_queue_size=max_queue_size,
#    1150       workers=workers,
#    1151       use_multiprocessing=use_multiprocessing,
#    1152       model=self,
#    1153       steps_per_execution=self._steps_per_execution)
#    1155   # Container that configures and calls `tf.keras.Callback`s.
#    1156   if not isinstance(callbacks, callbacks_module.CallbackList):
#
# File ~\anaconda3\envs\python3.9.0\lib\site-packages\tensorflow\python\keras\engine\data_adapter.py:1394, in get_data_handler(*args, **kwargs)
#    1392 if getattr(kwargs["model"], "_cluster_coordinator", None):
#    1393   return _ClusterCoordinatorDataHandler(*args, **kwargs)
# -> 1394 return DataHandler(*args, **kwargs)
#
# File ~\anaconda3\envs\python3.9.0\lib\site-packages\tensorflow\python\keras\engine\data_adapter.py:1149, in DataHandler.__init__(self, x, y, sample_weight, batch_size, steps_per_epoch, initial_epoch, epochs, shuffle, class_weight, max_queue_size, workers, use_multiprocessing, model, steps_per_execution, distribute)
#    1146   self._steps_per_execution_value = steps_per_execution.numpy().item()
#    1148 adapter_cls = select_data_adapter(x, y)
# -> 1149 self._adapter = adapter_cls(
#    1150     x,
#    1151     y,
#    1152     batch_size=batch_size,
#    1153     steps=steps_per_epoch,
#    1154     epochs=epochs - initial_epoch,
#    1155     sample_weights=sample_weight,
#    1156     shuffle=shuffle,
#    1157     max_queue_size=max_queue_size,
#    1158     workers=workers,
#    1159     use_multiprocessing=use_multiprocessing,
#    1160     distribution_strategy=ds_context.get_strategy(),
#    1161     model=model)
#    1163 strategy = ds_context.get_strategy()
#    1165 self._current_step = 0
#
# File ~\anaconda3\envs\python3.9.0\lib\site-packages\tensorflow\python\keras\engine\data_adapter.py:243, in TensorLikeDataAdapter.__init__(self, x, y, sample_weights, sample_weight_modes, batch_size, epochs, steps, shuffle, **kwargs)
#     232 def __init__(self,
#     233              x,
#     234              y=None,
#    (...)
#     240              shuffle=False,
#     241              **kwargs):
#     242   super(TensorLikeDataAdapter, self).__init__(x, y, **kwargs)
# --> 243   x, y, sample_weights = _process_tensorlike((x, y, sample_weights))
#     244   sample_weight_modes = broadcast_sample_weight_modes(
#     245       sample_weights, sample_weight_modes)
#     247   # If sample_weights are not specified for an output use 1.0 as weights.
#
# File ~\anaconda3\envs\python3.9.0\lib\site-packages\tensorflow\python\keras\engine\data_adapter.py:1042, in _process_tensorlike(inputs)
#    1039     return _scipy_sparse_to_sparse_tensor(x)
#    1040   return x
# -> 1042 inputs = nest.map_structure(_convert_numpy_and_scipy, inputs)
#    1043 return nest.list_to_tuple(inputs)
#
# File ~\anaconda3\envs\python3.9.0\lib\site-packages\tensorflow\python\util\nest.py:869, in map_structure(func, *structure, **kwargs)
#     865 flat_structure = (flatten(s, expand_composites) for s in structure)
#     866 entries = zip(*flat_structure)
#     868 return pack_sequence_as(
# --> 869     structure[0], [func(*x) for x in entries],
#     870     expand_composites=expand_composites)
#
# File ~\anaconda3\envs\python3.9.0\lib\site-packages\tensorflow\python\util\nest.py:869, in <listcomp>(.0)
#     865 flat_structure = (flatten(s, expand_composites) for s in structure)
#     866 entries = zip(*flat_structure)
#     868 return pack_sequence_as(
# --> 869     structure[0], [func(*x) for x in entries],
#     870     expand_composites=expand_composites)
#
# File ~\anaconda3\envs\python3.9.0\lib\site-packages\tensorflow\python\keras\engine\data_adapter.py:1037, in _process_tensorlike.<locals>._convert_numpy_and_scipy(x)
#    1035   if issubclass(x.dtype.type, np.floating):
#    1036     dtype = backend.floatx()
# -> 1037   return ops.convert_to_tensor_v2_with_dispatch(x, dtype=dtype)
#    1038 elif _is_scipy_sparse(x):
#    1039   return _scipy_sparse_to_sparse_tensor(x)
#
# File ~\anaconda3\envs\python3.9.0\lib\site-packages\tensorflow\python\util\traceback_utils.py:153, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
# --> 153   raise e.with_traceback(filtered_tb) from None
#     154 finally:
#     155   del filtered_tb
#
# File ~\anaconda3\envs\python3.9.0\lib\site-packages\tensorflow\python\framework\constant_op.py:106, in convert_to_eager_tensor(value, ctx, dtype)
#     104     dtype = dtypes.as_dtype(dtype).as_datatype_enum
#     105 ctx.ensure_initialized()
# --> 106 return ops.EagerTensor(value, ctx.device_name, dtype)
#
# InternalError: Failed copying input tensor from /job:localhost/replica:0/task:0/device:CPU:0 to /job:localhost/replica:0/task:0/device:GPU:0 in order to run _EagerConst: Dst tensor is not initialized.

# %%
y_test_.shape
# Out:
# (10920,)

# %% [markdown]
# # Test by many library images

# %%
X_train = []
X_test = []
y_train = []
y_test =[]

X = joblib.load("CV2_float32.pkl")
X_train_, X_test_, y_train_, y_test_ = train_test_split(X, y, stratify=y, shuffle=True, random_state=42)
X_train.append(X_train_), y_train.append(y_train_), X_test.append(X_test_), y_test.append(y_test_)

X = joblib.load("converted_img.pkl")
X_train_, X_test_, y_train_, y_test_ = train_test_split(X, y, stratify=y, shuffle=True, random_state=42)
X_train.append(X_train_), y_train.append(y_train_), X_test.append(X_test_), y_test.append(y_test_)

X = joblib.load("CV2_LANCZO.pkl")
X_train_, X_test_, y_train_, y_test_ = train_test_split(X, y, stratify=y, shuffle=True, random_state=42)
X_train.append(X_train_), y_train.append(y_train_), X_test.append(X_test_), y_test.append(y_test_)

X_train = np.float32(X_train)
X_test = np.float32(X_test)
y_train = np.float32(y_train)
y_test = np.float32(y_test)
X_train = X_train.reshape(-1, 32, 32, 3)
X_test = X_test.reshape(-1, 32, 32, 3)
y_train = y_train.reshape(-1)
y_test = y_test.reshape(-1)

# %%
X_train, y_train = make_train_data(transform_fiip)

# %%
y_train = encoder.transform(y_train.reshape(-1, 1))
y_test = encoder.transform(y_test.reshape(-1, 1))

# %%
dr_ratio=0.2

Input = keras.layers.Input(shape=X_train[0].shape)

x = keras.layers.Conv2D(16, kernel_size=3, activation="relu",kernel_initializer="he_normal", padding="same")(Input)
x = keras.layers.BatchNormalization()(x)
x = keras.layers.MaxPool2D(2)(x)

x = keras.layers.Dropout(dr_ratio)(x)

shortcut =x
x = keras.layers.Conv2D(32, kernel_size=3, activation="relu",kernel_initializer="he_normal", padding="same")(x)
x = keras.layers.BatchNormalization()(x)
x = keras.layers.Conv2D(32, kernel_size=3, activation="relu",kernel_initializer="he_normal", padding="same")(x)
# x = keras.layers.BatchNormalization()(x)
# x = keras.layers.Conv2D(32, kernel_size=3, activation="relu",kernel_initializer="he_normal", padding="same")(x)
shortcut = keras.layers.Conv2D(32, kernel_size=5, activation="relu",kernel_initializer="he_normal", padding="same")(shortcut)
x = keras.layers.Add()([x, shortcut])
x   = keras.layers.BatchNormalization()(x)
x = keras.layers.MaxPool2D(2)(x)


x = keras.layers.Dropout(dr_ratio)(x)


shortcut =x
x = keras.layers.Conv2D(64, kernel_size=3, activation="relu",kernel_initializer="he_normal", padding="same")(x)
x = keras.layers.BatchNormalization()(x)
x = keras.layers.Conv2D(64, kernel_size=3, activation="relu",kernel_initializer="he_normal", padding="same")(x)
# x = keras.layers.BatchNormalization()(x)
# x = keras.layers.Conv2D(64, kernel_size=3, activation="relu",kernel_initializer="he_normal", padding="same")(x)
shortcut = keras.layers.Conv2D(64, kernel_size=3, activation="relu",kernel_initializer="he_normal", padding="same")(shortcut)
x = keras.layers.Add()([x, shortcut])
x = keras.layers.BatchNormalization()(x)
x = keras.layers.MaxPool2D(2)(x)

x = keras.layers.Dropout(dr_ratio)(x)

shortcut =x
x = keras.layers.Conv2D(128, kernel_size=3, activation="relu",kernel_initializer="he_normal", padding="same")(x)
x = keras.layers.BatchNormalization()(x)
x = keras.layers.Conv2D(128, kernel_size=3, activation="relu",kernel_initializer="he_normal", padding="same")(x)
# x = keras.layers.BatchNormalization()(x)
# x = keras.layers.Conv2D(128, kernel_size=3, activation="relu",kernel_initializer="he_normal", padding="same")(x)
shortcut = keras.layers.Conv2D(128, kernel_size=3, activation="relu",kernel_initializer="he_normal", padding="same")(shortcut)
x = keras.layers.Add()([x, shortcut])
x = keras.layers.BatchNormalization()(x)
x = keras.layers.MaxPool2D(2)(x)

x = keras.layers.Dropout(dr_ratio)(x)


x = keras.layers.GlobalAveragePooling2D()(x)
Output = keras.layers.Dense(4, activation="softmax")(x)

model = keras.models.Model(inputs = Input, outputs = Output)
model.compile(loss="categorical_crossentropy",
optimizer=keras.optimizers.Adam(learning_rate=0.001), metrics=["accuracy"])

history=model.fit(X_train, y_train, validation_data=(X_test, y_test),callbacks=[es, reduce_lr],epochs = 100)
print("Train: ", model.evaluate(X_train, y_train))
print("Valid: ", model.evaluate(X_test, y_test))
# Out:
# Epoch 1/100
# 5119/5119 [==============================] - 59s 11ms/step - loss: 0.1962 - accuracy: 0.9238 - val_loss: 0.8435 - val_accuracy: 0.7590
# Epoch 2/100
# 5119/5119 [==============================] - 57s 11ms/step - loss: 0.0560 - accuracy: 0.9798 - val_loss: 0.8832 - val_accuracy: 0.7647
# Epoch 3/100
# 5119/5119 [==============================] - 58s 11ms/step - loss: 0.0337 - accuracy: 0.9880 - val_loss: 0.9018 - val_accuracy: 0.8125
# 5119/5119 [==============================] - 55s 11ms/step - loss: 5.9618e-04 - accuracy: 0.9998 - val_loss: 0.0019 - val_accuracy: 0.9993
# Epoch 24/100
# 5119/5119 [==============================] - 55s 11ms/step - loss: 4.7247e-04 - accuracy: 0.9999 - val_loss: 0.0020 - val_accuracy: 0.9993
# Epoch 25/100
# 5119/5119 [==============================] - 55s 11ms/step - loss: 5.8364e-04 - accuracy: 0.9998 - val_loss: 0.0053 - val_accuracy: 0.9982
#
# Epoch 00025: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# Epoch 26/100
# 5119/5119 [==============================] - 55s 11ms/step - loss: 4.9184e-04 - accuracy: 0.9999 - val_loss: 0.0015 - val_accuracy: 0.9993
# Epoch 27/100
# 5119/5119 [==============================] - 55s 11ms/step - loss: 4.4964e-04 - accuracy: 0.9999 - val_loss: 0.0012 - val_accuracy: 0.9993
# Epoch 28/100
# 5119/5119 [==============================] - 55s 11ms/step - loss: 3.8451e-04 - accuracy: 0.9999 - val_loss: 0.0030 - val_accuracy: 0.9996
#
# Epoch 00028: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# Epoch 29/100
# 5119/5119 [==============================] - 55s 11ms/step - loss: 4.2558e-04 - accuracy: 0.9999 - val_loss: 0.0013 - val_accuracy: 0.9991
# Epoch 30/100
# 5119/5119 [==============================] - 55s 11ms/step - loss: 2.3468e-04 - accuracy: 0.9999 - val_loss: 8.4227e-04 - val_accuracy: 0.9998
# Epoch 31/100
# 5119/5119 [==============================] - 55s 11ms/step - loss: 2.3380e-04 - accuracy: 0.9999 - val_loss: 0.0025 - val_accuracy: 0.9991
#
# Epoch 00031: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# Epoch 32/100
# 5119/5119 [==============================] - 55s 11ms/step - loss: 2.7140e-04 - accuracy: 0.9999 - val_loss: 0.0010 - val_accuracy: 0.9995
# ---------------------------------------------------------------------------
# InternalError                             Traceback (most recent call last)
# Input In [96], in <cell line: 61>()
#      57 model.compile(loss="categorical_crossentropy",
#      58 optimizer=keras.optimizers.Adam(learning_rate=0.001), metrics=["accuracy"])
#      60 history=model.fit(X_train, y_train, validation_data=(X_test, y_test),callbacks=[es, reduce_lr],epochs = 100)
# ---> 61 print("Train: ", model.evaluate(X_train, y_train))
#      62 print("Valid: ", model.evaluate(X_test, y_test))
#
# File ~\anaconda3\envs\python3.9.0\lib\site-packages\tensorflow\python\keras\engine\training.py:1464, in Model.evaluate(self, x, y, batch_size, verbose, sample_weight, steps, callbacks, max_queue_size, workers, use_multiprocessing, return_dict, **kwargs)
#    1461   data_handler = self._eval_data_handler
#    1462 else:
#    1463   # Creates a `tf.data.Dataset` and handles batch and epoch iteration.
# -> 1464   data_handler = data_adapter.get_data_handler(
#    1465       x=x,
#    1466       y=y,
#    1467       sample_weight=sample_weight,
#    1468       batch_size=batch_size,
#    1469       steps_per_epoch=steps,
#    1470       initial_epoch=0,
#    1471       epochs=1,
#    1472       max_queue_size=max_queue_size,
#    1473       workers=workers,
#    1474       use_multiprocessing=use_multiprocessing,
#    1475       model=self,
#    1476       steps_per_execution=self._steps_per_execution)
#    1478 # Container that configures and calls `tf.keras.Callback`s.
#    1479 if not isinstance(callbacks, callbacks_module.CallbackList):
#
# File ~\anaconda3\envs\python3.9.0\lib\site-packages\tensorflow\python\keras\engine\data_adapter.py:1394, in get_data_handler(*args, **kwargs)
#    1392 if getattr(kwargs["model"], "_cluster_coordinator", None):
#    1393   return _ClusterCoordinatorDataHandler(*args, **kwargs)
# -> 1394 return DataHandler(*args, **kwargs)
#
# File ~\anaconda3\envs\python3.9.0\lib\site-packages\tensorflow\python\keras\engine\data_adapter.py:1149, in DataHandler.__init__(self, x, y, sample_weight, batch_size, steps_per_epoch, initial_epoch, epochs, shuffle, class_weight, max_queue_size, workers, use_multiprocessing, model, steps_per_execution, distribute)
#    1146   self._steps_per_execution_value = steps_per_execution.numpy().item()
#    1148 adapter_cls = select_data_adapter(x, y)
# -> 1149 self._adapter = adapter_cls(
#    1150     x,
#    1151     y,
#    1152     batch_size=batch_size,
#    1153     steps=steps_per_epoch,
#    1154     epochs=epochs - initial_epoch,
#    1155     sample_weights=sample_weight,
#    1156     shuffle=shuffle,
#    1157     max_queue_size=max_queue_size,
#    1158     workers=workers,
#    1159     use_multiprocessing=use_multiprocessing,
#    1160     distribution_strategy=ds_context.get_strategy(),
#    1161     model=model)
#    1163 strategy = ds_context.get_strategy()
#    1165 self._current_step = 0
#
# File ~\anaconda3\envs\python3.9.0\lib\site-packages\tensorflow\python\keras\engine\data_adapter.py:243, in TensorLikeDataAdapter.__init__(self, x, y, sample_weights, sample_weight_modes, batch_size, epochs, steps, shuffle, **kwargs)
#     232 def __init__(self,
#     233              x,
#     234              y=None,
#    (...)
#     240              shuffle=False,
#     241              **kwargs):
#     242   super(TensorLikeDataAdapter, self).__init__(x, y, **kwargs)
# --> 243   x, y, sample_weights = _process_tensorlike((x, y, sample_weights))
#     244   sample_weight_modes = broadcast_sample_weight_modes(
#     245       sample_weights, sample_weight_modes)
#     247   # If sample_weights are not specified for an output use 1.0 as weights.
#
# File ~\anaconda3\envs\python3.9.0\lib\site-packages\tensorflow\python\keras\engine\data_adapter.py:1042, in _process_tensorlike(inputs)
#    1039     return _scipy_sparse_to_sparse_tensor(x)
#    1040   return x
# -> 1042 inputs = nest.map_structure(_convert_numpy_and_scipy, inputs)
#    1043 return nest.list_to_tuple(inputs)
#
# File ~\anaconda3\envs\python3.9.0\lib\site-packages\tensorflow\python\util\nest.py:869, in map_structure(func, *structure, **kwargs)
#     865 flat_structure = (flatten(s, expand_composites) for s in structure)
#     866 entries = zip(*flat_structure)
#     868 return pack_sequence_as(
# --> 869     structure[0], [func(*x) for x in entries],
#     870     expand_composites=expand_composites)
#
# File ~\anaconda3\envs\python3.9.0\lib\site-packages\tensorflow\python\util\nest.py:869, in <listcomp>(.0)
#     865 flat_structure = (flatten(s, expand_composites) for s in structure)
#     866 entries = zip(*flat_structure)
#     868 return pack_sequence_as(
# --> 869     structure[0], [func(*x) for x in entries],
#     870     expand_composites=expand_composites)
#
# File ~\anaconda3\envs\python3.9.0\lib\site-packages\tensorflow\python\keras\engine\data_adapter.py:1037, in _process_tensorlike.<locals>._convert_numpy_and_scipy(x)
#    1035   if issubclass(x.dtype.type, np.floating):
#    1036     dtype = backend.floatx()
# -> 1037   return ops.convert_to_tensor_v2_with_dispatch(x, dtype=dtype)
#    1038 elif _is_scipy_sparse(x):
#    1039   return _scipy_sparse_to_sparse_tensor(x)
#
# File ~\anaconda3\envs\python3.9.0\lib\site-packages\tensorflow\python\util\traceback_utils.py:153, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
# --> 153   raise e.with_traceback(filtered_tb) from None
#     154 finally:
#     155   del filtered_tb
#
# File ~\anaconda3\envs\python3.9.0\lib\site-packages\tensorflow\python\framework\constant_op.py:106, in convert_to_eager_tensor(value, ctx, dtype)
#     104     dtype = dtypes.as_dtype(dtype).as_datatype_enum
#     105 ctx.ensure_initialized()
# --> 106 return ops.EagerTensor(value, ctx.device_name, dtype)
#
# InternalError: Failed copying input tensor from /job:localhost/replica:0/task:0/device:CPU:0 to /job:localhost/replica:0/task:0/device:GPU:0 in order to run _EagerConst: Dst tensor is not initialized.
